# %% [markdown]
# # Tables, csv-files and shape-files for the manuscript
#
# Author: Thiago Nascimento (thiago.nascimento@eawag.ch)
#
# This notebook is part of the EStreams publication and was used to pre-process and derive tables and files for the manuscript.
#
# * Note that this code enables not only the replicability of the current database but also the extrapolation to new catchment areas.
# * Additionally, the user should download and insert the original raw-data in the folder of the same name prior to run this code.
# * The original third-party data used were not made avaialble in this repository due to redistribution and storage-space reasons.
#
# ## Requirements
# **Python:**
#
# * Python>=3.6
# * Jupyter
# * Geopandas=0.10.2
# * Pandas
# * tqdm
#
# Check the Github repository for an environment.yml (for conda environments) or requirements.txt (pip) file.
#
# **Files:**
#
# * Daily streamflow measurements.
#
# **Directory:**
#
# * Clone the GitHub directory locally
# * Place any third-data variables in their respective directory.
# * ONLY update the "PATH" variable in the section "Configurations", with their relative path to the EStreams directory.

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import datetime
import tqdm as tqdm
import os
import geopandas as gpd
from utils.general import *

# %% [markdown]
# # Configurations

# %%
# Only editable variable:
PATH = r"/Users/thiagomedeirosdonascimento/Library/CloudStorage/OneDrive-Personal/PhD/Eawag/Papers/Paper1_Database/Paper"

# %% [markdown]
# * #### The users should NOT change anything in the code below here.

# %%
PATH_OUTPUT = "results/"

# Set the directory:
os.chdir(PATH)

# %% [markdown]
# # Import data
# ## Catchment boundaries

# %%
catchment_boundaries = gpd.read_file('data/shapefiles/estreams_catchments.shp')
catchment_boundaries
# Out:
#             id area_km2  outlet_lat  outlet_lng area_offic   area_calc  \
# 0      DE01945  144,000   50.937000    6.963000     144232  144432.885
# 1      DE01946  148,000   51.226000    6.770000     147680  147934.665
# 2      DE01947  144,000   50.937000    6.963000     144232  144432.885
# 3      DE01948  148,000   51.226000    6.770000     147680  147934.665
# 4      DE01949  159,000   51.757000    6.395000     159300  159352.653
# ...        ...      ...         ...         ...        ...         ...
# 15009  NL00015      148   51.812000    4.566000       None     148.000
# 15010  NL00016     9500   51.350000    4.251000       None    9500.000
# 15011  NL00017    21300   50.830000    5.697000       None   21300.000
# 15012  NL00014     3229   52.342353    6.103294       None    3229.000
# 15013  CZ00451      314   49.231000   17.672000     312.69     314.118
#
#           Code basin_id label_area                    name  \
# 0      DE01945  DE01945          0        BundespegelKoeln
# 1      DE01946  DE01946          0  BundespegelDuesseldorf
# 2      DE01947  DE01947          0        BundespegelKoeln
# 3      DE01948  DE01948          0  BundespegelDuesseldorf
# 4      DE01949  DE01949          0         BundespegelRees
# ...        ...      ...        ...                     ...
# 15009  NL00015  NL00015        888             Puttershoek
# 15010  NL00016  NL00016          4   Schaar van Ouden Doel
# 15011  NL00017  NL00017          4       Sint Pieter noord
# 15012  NL00014  NL00014          6                    Olst
# 15013  CZ00451  CZ00451          0            ZlÃÂ­n+svod
#
#                                layer  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# ...                              ...
# 15009  Catchment_Boundaries_NL_Merge
# 15010  Catchment_Boundaries_NL_Merge
# 15011  Catchment_Boundaries_NL_Merge
# 15012  Catchment_Boundaries_NL_Merge
# 15013                           None
#
#                                                     path  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 15009  C:\Users\nascimth\Documents\Thiago\Eawag\Pytho...
# 15010  C:\Users\nascimth\Documents\Thiago\Eawag\Pytho...
# 15011  C:\Users\nascimth\Documents\Thiago\Eawag\Pytho...
# 15012  C:\Users\nascimth\Documents\Thiago\Eawag\Pytho...
# 15013                                               None
#
#                                                 geometry
# 0      POLYGON Z ((7.96208 46.53708 0.00000, 7.96625 ...
# 1      POLYGON Z ((7.96208 46.53708 0.00000, 7.96625 ...
# 2      POLYGON Z ((7.96208 46.53708 0.00000, 7.96625 ...
# 3      POLYGON Z ((7.96208 46.53708 0.00000, 7.96625 ...
# 4      POLYGON Z ((7.96208 46.53708 0.00000, 7.96625 ...
# ...                                                  ...
# 15009  POLYGON Z ((4.49041 51.82958 0.00000, 4.49041 ...
# 15010  POLYGON Z ((4.18958 51.29875 0.00000, 4.18958 ...
# 15011  POLYGON Z ((4.45041 49.91875 0.00000, 4.45041 ...
# 15012  POLYGON Z ((6.60946 52.15346 0.00000, 6.60837 ...
# 15013  POLYGON Z ((17.67541 49.24125 0.00000, 17.6754...
#
# [15014 rows x 13 columns]

# %%
# Here we sort the index:
catchment_boundaries = catchment_boundaries.set_index("id", inplace=False).sort_index(axis=0)
catchment_boundaries
# Out:
#                    area_km2  outlet_lat  outlet_lng area_offic  area_calc  \
# id
# AT00001   4668.378643009853      47.274       9.535     4647.9   4668.379
# AT00002  102.28688127787842      47.080       9.914        102    102.287
# AT00003   536.2985313168554      47.133       9.848      535.2    536.299
# AT00004    66.2856923321305      47.129      10.062       66.6     66.286
# AT00005    72.4477297164234      47.151       9.803       72.2     72.448
# ...                     ...         ...         ...        ...        ...
# UAGR017                 325      44.692      33.895        321    325.370
# UAGR018                  48      44.500      34.167       49.7     47.594
# UAGR019                 245      44.888      34.200        261    244.731
# UAGR020                 731      47.251      35.706        760    731.073
# UAGR021                 600      48.153      38.145        582    599.600
#
#             Code basin_id label_area                 name layer  path  \
# id
# AT00001  AT00001  AT00001          0                Bangs  None  None
# AT00002  AT00002  AT00002          0  Schruns (Vonbunweg)  None  None
# AT00003  AT00003  AT00003          0        Loruens-Aeule  None  None
# AT00004  AT00004  AT00004          0    Kloesterle (OEBB)  None  None
# AT00005  AT00005  AT00005          0  Buers (Bruecke L82)  None  None
# ...          ...      ...        ...                  ...   ...   ...
# UAGR017  UAGR017  UAGR017          0              6682300  None  None
# UAGR018  UAGR018  UAGR018          0              6682500  None  None
# UAGR019  UAGR019  UAGR019          1              6683010  None  None
# UAGR020  UAGR020  UAGR020          0              6683200  None  None
# UAGR021  UAGR021  UAGR021          0              6683300  None  None
#
#                                                   geometry
# id
# AT00001  POLYGON Z ((9.69406 46.54322 0.00000, 9.69570 ...
# AT00002  POLYGON Z ((10.13650 47.02949 0.00000, 10.1349...
# AT00003  POLYGON Z ((10.11095 46.89437 0.00000, 10.1122...
# AT00004  POLYGON Z ((10.14189 47.09706 0.00000, 10.1404...
# AT00005  POLYGON Z ((9.67851 47.06249 0.00000, 9.67888 ...
# ...                                                    ...
# UAGR017  POLYGON Z ((33.96791 44.63291 0.00000, 33.9679...
# UAGR018  POLYGON Z ((34.19958 44.58291 0.00000, 34.2029...
# UAGR019  POLYGON Z ((34.19624 44.88375 0.00000, 34.1962...
# UAGR020  POLYGON Z ((35.78708 47.28708 0.00000, 35.7870...
# UAGR021  POLYGON Z ((38.10125 48.15791 0.00000, 38.1004...
#
# [15014 rows x 12 columns]

# %% [markdown]
# ## Europe

# %%
shapefile_path = "data/shapefiles/europe.shp"
europe = gpd.read_file(shapefile_path)

# %% [markdown]
# ## Daily streamflow time-series

# %%
timeseries_EU = pd.read_csv("data/streamflow/estreams_timeseries_streamflow.csv", index_col=0)
timeseries_EU.index = pd.to_datetime(timeseries_EU.index)
timeseries_EU.index.name = "dates"
timeseries_EU
# Out:
#             AT00001  AT00002  AT00003  AT00004  AT00005  AT00006  AT00007  \
# dates
# 1900-01-01      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-02      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-03      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-04      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-27      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#             AT00008  AT00009  AT00010  ...  DE02101  DE02102  DE02103  \
# dates                                  ...
# 1900-01-01      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 1900-01-02      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 1900-01-03      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 1900-01-04      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 1900-01-05      NaN      NaN      NaN  ...      NaN      NaN      NaN
# ...             ...      ...      ...  ...      ...      ...      ...
# 2023-12-27      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 2023-12-28      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 2023-12-29      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 2023-12-30      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 2023-12-31      NaN      NaN      NaN  ...      NaN      NaN      NaN
#
#             DE02104  DE02105  DE02106  DE02107  DE02108  DE02109  DE02110
# dates
# 1900-01-01      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-02      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-03      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-04      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1900-01-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-27      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [45290 rows x 15046 columns]

# %%
# Replace any negative value by np.nan:
timeseries_EU = timeseries_EU.applymap(lambda x: np.nan if x < 0 else x)

# %% [markdown]
# ## Streamflow gauges network

# %%
network_EU = pd.read_excel("data/streamflow/estreams_gauging_stations_infos.xlsx")
network_EU
# Out:
#        new_code        code                        name     river     area  \
# 0      ITVEN406       270VE            Adige a Albaredo     Adige  11954.0
# 1      ITVEN407       283VE           Brenta a Barzizza    Brenta   1567.0
# 2      ITVEN408       284VE        Adige a Boara Pisani     Adige  11954.0
# 3      ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina    694.0
# 4      ITVEN410       286VE    Frassine a Borgofrassine  Frassine      NaN
# ...         ...         ...                         ...       ...      ...
# 15041   DE02106  5752400000                  Hachelbich    Wipper    524.0
# 15042   DE02107  5752500000                 Bleicherode      Bode    104.0
# 15043   DE02108  5754000000                  Sundhausen     Helme    200.6
# 15044   DE02109  5755000000                  Nordhausen     Zorge    303.6
# 15045   DE02110  5756600000                      Ilfeld      Bere     62.3
#
#          elev        lon        lat country degimpact  ...  calc_Perc2  \
# 0       23.59  11.266291  45.317948      IT       NaN  ...         NaN
# 1      105.38  11.730543  45.777415      IT       NaN  ...         NaN
# 2         8.4  11.784244  45.105481      IT       NaN  ...         NaN
# 3       37.57  11.620895  45.600894      IT       NaN  ...         NaN
# 4       16.69  11.481112  45.251409      IT       NaN  ...         NaN
# ...       ...        ...        ...     ...       ...  ...         ...
# 15041     NaN  10.973000  51.347000      DE       NaN  ...         NaN
# 15042     NaN  10.593000  51.450000      DE       NaN  ...         NaN
# 15043     NaN  10.810000  51.468000      DE       NaN  ...         NaN
# 15044     NaN  10.784000  51.507000      DE       NaN  ...         NaN
# 15045     NaN  10.786000  51.598000      DE       NaN  ...         NaN
#
#        error_are2 xcoord_3  ycoord_3  manual_del  area_calc  area_calc_  \
# 0             NaN      NaN       NaN         NaN  11938.762         0.0
# 1             NaN      NaN       NaN         NaN   1571.329         0.0
# 2             NaN      NaN       NaN         NaN  12020.860         0.0
# 3             NaN      NaN       NaN         NaN    759.659         0.0
# 4             NaN      NaN       NaN         NaN    414.418         2.0
# ...           ...      ...       ...         ...        ...         ...
# 15041         NaN      NaN       NaN         NaN    524.000         0.0
# 15042         NaN      NaN       NaN         NaN    104.000         0.0
# 15043         NaN      NaN       NaN         NaN    200.000         0.0
# 15044         NaN      NaN       NaN         NaN    302.000         0.0
# 15045         NaN      NaN       NaN         NaN     63.000         0.0
#
#        area_calc_label  region  remark
# 0                    0     NaN     NaN
# 1                    0     NaN     NaN
# 2                    0     NaN     NaN
# 3                    0     NaN     NaN
# 4                    2     NaN     NaN
# ...                ...     ...     ...
# 15041                0      TH     NaN
# 15042                0      TH     NaN
# 15043                0      TH     NaN
# 15044                0      TH     NaN
# 15045                0      TH     NaN
#
# [15046 rows x 37 columns]

# %%
network_EU.columns
# Out:
# Index(['new_code', 'code', 'name', 'river', 'area', 'elev', 'lon', 'lat',
#        'country', 'degimpact', 'lake', 'num_reserv', 'RE', 'num_daily_',
#        'num_years_', 'delete', 'calc_Perc_', 'xcoord', 'ycoord', 'xcoord_4',
#        'ycoord_4', 'calc_area_', 'new_area', 'error_area', 'xcoord_2',
#        'ycoord_2', 'new_area2', 'calc_Perc2', 'error_are2', 'xcoord_3',
#        'ycoord_3', 'manual_del', 'area_calc', 'area_calc_', 'area_calc_label',
#        'region', 'remark'],
#       dtype='object')

# %%
network_EU[["new_code", "code"]]
# Out:
#        new_code        code
# 0      ITVEN406       270VE
# 1      ITVEN407       283VE
# 2      ITVEN408       284VE
# 3      ITVEN409       285VE
# 4      ITVEN410       286VE
# ...         ...         ...
# 15041   DE02106  5752400000
# 15042   DE02107  5752500000
# 15043   DE02108  5754000000
# 15044   DE02109  5755000000
# 15045   DE02110  5756600000
#
# [15046 rows x 2 columns]

# %%
network_EU_net = network_EU[["new_code", "code", "name", "river", "xcoord_4", "ycoord_4", "lon", "lat",
                           "area", "elev", "country", "area_calc", "area_calc_label"]]

network_EU_net.columns = ["basin_id", "gauge_id", "gauge_name ", "river", "lon", "lat", "lon_r","lat_r", 
                          "area_r", "elevation", "country", "area_c", "area_flag"]

network_EU_net
# Out:
#        basin_id    gauge_id                 gauge_name      river        lon  \
# 0      ITVEN406       270VE            Adige a Albaredo     Adige  11.266291
# 1      ITVEN407       283VE           Brenta a Barzizza    Brenta  11.730543
# 2      ITVEN408       284VE        Adige a Boara Pisani     Adige  11.784244
# 3      ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina  11.620895
# 4      ITVEN410       286VE    Frassine a Borgofrassine  Frassine  11.481112
# ...         ...         ...                         ...       ...        ...
# 15041   DE02106  5752400000                  Hachelbich    Wipper  10.973000
# 15042   DE02107  5752500000                 Bleicherode      Bode  10.593000
# 15043   DE02108  5754000000                  Sundhausen     Helme  10.810000
# 15044   DE02109  5755000000                  Nordhausen     Zorge  10.784000
# 15045   DE02110  5756600000                      Ilfeld      Bere  10.786000
#
#              lat      lon_r      lat_r   area_r elevation country     area_c  \
# 0      45.317948  11.266291  45.317948  11954.0     23.59      IT  11938.762
# 1      45.777415  11.730543  45.777415   1567.0    105.38      IT   1571.329
# 2      45.105481  11.784244  45.105481  11954.0       8.4      IT  12020.860
# 3      45.600894  11.620895  45.600894    694.0     37.57      IT    759.659
# 4      45.251409  11.481112  45.251409      NaN     16.69      IT    414.418
# ...          ...        ...        ...      ...       ...     ...        ...
# 15041  51.347000  10.973000  51.347000    524.0       NaN      DE    524.000
# 15042  51.450000  10.593000  51.450000    104.0       NaN      DE    104.000
# 15043  51.468000  10.810000  51.468000    200.6       NaN      DE    200.000
# 15044  51.507000  10.784000  51.507000    303.6       NaN      DE    302.000
# 15045  51.598000  10.786000  51.598000     62.3       NaN      DE     63.000
#
#        area_flag
# 0              0
# 1              0
# 2              0
# 3              0
# 4              2
# ...          ...
# 15041          0
# 15042          0
# 15043          0
# 15044          0
# 15045          0
#
# [15046 rows x 13 columns]

# %%
network_EU_net["area_perc"] = ((network_EU_net["area_r"] - network_EU_net["area_c"])/network_EU_net["area_r"])  * 100

# %%
network_EU_net
# Out:
#        basin_id    gauge_id                 gauge_name      river        lon  \
# 0      ITVEN406       270VE            Adige a Albaredo     Adige  11.266291
# 1      ITVEN407       283VE           Brenta a Barzizza    Brenta  11.730543
# 2      ITVEN408       284VE        Adige a Boara Pisani     Adige  11.784244
# 3      ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina  11.620895
# 4      ITVEN410       286VE    Frassine a Borgofrassine  Frassine  11.481112
# ...         ...         ...                         ...       ...        ...
# 15041   DE02106  5752400000                  Hachelbich    Wipper  10.973000
# 15042   DE02107  5752500000                 Bleicherode      Bode  10.593000
# 15043   DE02108  5754000000                  Sundhausen     Helme  10.810000
# 15044   DE02109  5755000000                  Nordhausen     Zorge  10.784000
# 15045   DE02110  5756600000                      Ilfeld      Bere  10.786000
#
#              lat      lon_r      lat_r   area_r elevation country     area_c  \
# 0      45.317948  11.266291  45.317948  11954.0     23.59      IT  11938.762
# 1      45.777415  11.730543  45.777415   1567.0    105.38      IT   1571.329
# 2      45.105481  11.784244  45.105481  11954.0       8.4      IT  12020.860
# 3      45.600894  11.620895  45.600894    694.0     37.57      IT    759.659
# 4      45.251409  11.481112  45.251409      NaN     16.69      IT    414.418
# ...          ...        ...        ...      ...       ...     ...        ...
# 15041  51.347000  10.973000  51.347000    524.0       NaN      DE    524.000
# 15042  51.450000  10.593000  51.450000    104.0       NaN      DE    104.000
# 15043  51.468000  10.810000  51.468000    200.6       NaN      DE    200.000
# 15044  51.507000  10.784000  51.507000    303.6       NaN      DE    302.000
# 15045  51.598000  10.786000  51.598000     62.3       NaN      DE     63.000
#
#        area_flag  area_perc
# 0              0   0.127472
# 1              0  -0.276260
# 2              0  -0.559311
# 3              0  -9.460951
# 4              2        NaN
# ...          ...        ...
# 15041          0   0.000000
# 15042          0   0.000000
# 15043          0   0.299103
# 15044          0   0.527009
# 15045          0  -1.123596
#
# [15046 rows x 14 columns]

# %%
# Here we set the index:
network_EU_net.set_index("basin_id", inplace =True)
network_EU_net
# Out:
#             gauge_id                 gauge_name      river        lon  \
# basin_id
# ITVEN406       270VE            Adige a Albaredo     Adige  11.266291
# ITVEN407       283VE           Brenta a Barzizza    Brenta  11.730543
# ITVEN408       284VE        Adige a Boara Pisani     Adige  11.784244
# ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina  11.620895
# ITVEN410       286VE    Frassine a Borgofrassine  Frassine  11.481112
# ...              ...                         ...       ...        ...
# DE02106   5752400000                  Hachelbich    Wipper  10.973000
# DE02107   5752500000                 Bleicherode      Bode  10.593000
# DE02108   5754000000                  Sundhausen     Helme  10.810000
# DE02109   5755000000                  Nordhausen     Zorge  10.784000
# DE02110   5756600000                      Ilfeld      Bere  10.786000
#
#                 lat      lon_r      lat_r   area_r elevation country  \
# basin_id
# ITVEN406  45.317948  11.266291  45.317948  11954.0     23.59      IT
# ITVEN407  45.777415  11.730543  45.777415   1567.0    105.38      IT
# ITVEN408  45.105481  11.784244  45.105481  11954.0       8.4      IT
# ITVEN409  45.600894  11.620895  45.600894    694.0     37.57      IT
# ITVEN410  45.251409  11.481112  45.251409      NaN     16.69      IT
# ...             ...        ...        ...      ...       ...     ...
# DE02106   51.347000  10.973000  51.347000    524.0       NaN      DE
# DE02107   51.450000  10.593000  51.450000    104.0       NaN      DE
# DE02108   51.468000  10.810000  51.468000    200.6       NaN      DE
# DE02109   51.507000  10.784000  51.507000    303.6       NaN      DE
# DE02110   51.598000  10.786000  51.598000     62.3       NaN      DE
#
#              area_c  area_flag  area_perc
# basin_id
# ITVEN406  11938.762          0   0.127472
# ITVEN407   1571.329          0  -0.276260
# ITVEN408  12020.860          0  -0.559311
# ITVEN409    759.659          0  -9.460951
# ITVEN410    414.418          2        NaN
# ...             ...        ...        ...
# DE02106     524.000          0   0.000000
# DE02107     104.000          0   0.000000
# DE02108     200.000          0   0.299103
# DE02109     302.000          0   0.527009
# DE02110      63.000          0  -1.123596
#
# [15046 rows x 13 columns]

# %%
network_EU_net["start_date"] = find_first_non_nan_dates(timeseries_EU)
network_EU_net["end_date"] = find_last_non_nan_dates(timeseries_EU)

network_EU_net
# Out:
#             gauge_id                 gauge_name      river        lon  \
# basin_id
# ITVEN406       270VE            Adige a Albaredo     Adige  11.266291
# ITVEN407       283VE           Brenta a Barzizza    Brenta  11.730543
# ITVEN408       284VE        Adige a Boara Pisani     Adige  11.784244
# ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina  11.620895
# ITVEN410       286VE    Frassine a Borgofrassine  Frassine  11.481112
# ...              ...                         ...       ...        ...
# DE02106   5752400000                  Hachelbich    Wipper  10.973000
# DE02107   5752500000                 Bleicherode      Bode  10.593000
# DE02108   5754000000                  Sundhausen     Helme  10.810000
# DE02109   5755000000                  Nordhausen     Zorge  10.784000
# DE02110   5756600000                      Ilfeld      Bere  10.786000
#
#                 lat      lon_r      lat_r   area_r elevation country  \
# basin_id
# ITVEN406  45.317948  11.266291  45.317948  11954.0     23.59      IT
# ITVEN407  45.777415  11.730543  45.777415   1567.0    105.38      IT
# ITVEN408  45.105481  11.784244  45.105481  11954.0       8.4      IT
# ITVEN409  45.600894  11.620895  45.600894    694.0     37.57      IT
# ITVEN410  45.251409  11.481112  45.251409      NaN     16.69      IT
# ...             ...        ...        ...      ...       ...     ...
# DE02106   51.347000  10.973000  51.347000    524.0       NaN      DE
# DE02107   51.450000  10.593000  51.450000    104.0       NaN      DE
# DE02108   51.468000  10.810000  51.468000    200.6       NaN      DE
# DE02109   51.507000  10.784000  51.507000    303.6       NaN      DE
# DE02110   51.598000  10.786000  51.598000     62.3       NaN      DE
#
#              area_c  area_flag  area_perc start_date   end_date
# basin_id
# ITVEN406  11938.762          0   0.127472 2005-07-07 2022-12-31
# ITVEN407   1571.329          0  -0.276260 2004-01-01 2022-12-31
# ITVEN408  12020.860          0  -0.559311 2004-01-01 2022-12-31
# ITVEN409    759.659          0  -9.460951 2004-01-01 2022-12-31
# ITVEN410    414.418          2        NaN 2012-11-11 2020-12-31
# ...             ...        ...        ...        ...        ...
# DE02106     524.000          0   0.000000 1961-11-01 2021-12-31
# DE02107     104.000          0   0.000000 1951-11-01 2021-12-31
# DE02108     200.000          0   0.299103 1957-11-01 2021-12-31
# DE02109     302.000          0   0.527009 1953-11-01 2021-12-31
# DE02110      63.000          0  -1.123596 1951-11-01 2021-12-31
#
# [15046 rows x 15 columns]

# %%
# Number of measurements:
network_EU_net[["num_daily_obs", "num_monthly", "num_monthly_complete", "num_yearly", "num_yearly_complete"]] = count_num_measurements(timeseries = timeseries_EU)
network_EU_net.drop(["num_monthly_complete", "num_yearly_complete"], axis = 1, inplace = True)
network_EU_net
# Out:
#             gauge_id                 gauge_name      river        lon  \
# basin_id
# ITVEN406       270VE            Adige a Albaredo     Adige  11.266291
# ITVEN407       283VE           Brenta a Barzizza    Brenta  11.730543
# ITVEN408       284VE        Adige a Boara Pisani     Adige  11.784244
# ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina  11.620895
# ITVEN410       286VE    Frassine a Borgofrassine  Frassine  11.481112
# ...              ...                         ...       ...        ...
# DE02106   5752400000                  Hachelbich    Wipper  10.973000
# DE02107   5752500000                 Bleicherode      Bode  10.593000
# DE02108   5754000000                  Sundhausen     Helme  10.810000
# DE02109   5755000000                  Nordhausen     Zorge  10.784000
# DE02110   5756600000                      Ilfeld      Bere  10.786000
#
#                 lat      lon_r      lat_r   area_r elevation country  \
# basin_id
# ITVEN406  45.317948  11.266291  45.317948  11954.0     23.59      IT
# ITVEN407  45.777415  11.730543  45.777415   1567.0    105.38      IT
# ITVEN408  45.105481  11.784244  45.105481  11954.0       8.4      IT
# ITVEN409  45.600894  11.620895  45.600894    694.0     37.57      IT
# ITVEN410  45.251409  11.481112  45.251409      NaN     16.69      IT
# ...             ...        ...        ...      ...       ...     ...
# DE02106   51.347000  10.973000  51.347000    524.0       NaN      DE
# DE02107   51.450000  10.593000  51.450000    104.0       NaN      DE
# DE02108   51.468000  10.810000  51.468000    200.6       NaN      DE
# DE02109   51.507000  10.784000  51.507000    303.6       NaN      DE
# DE02110   51.598000  10.786000  51.598000     62.3       NaN      DE
#
#              area_c  area_flag  area_perc start_date   end_date  \
# basin_id
# ITVEN406  11938.762          0   0.127472 2005-07-07 2022-12-31
# ITVEN407   1571.329          0  -0.276260 2004-01-01 2022-12-31
# ITVEN408  12020.860          0  -0.559311 2004-01-01 2022-12-31
# ITVEN409    759.659          0  -9.460951 2004-01-01 2022-12-31
# ITVEN410    414.418          2        NaN 2012-11-11 2020-12-31
# ...             ...        ...        ...        ...        ...
# DE02106     524.000          0   0.000000 1961-11-01 2021-12-31
# DE02107     104.000          0   0.000000 1951-11-01 2021-12-31
# DE02108     200.000          0   0.299103 1957-11-01 2021-12-31
# DE02109     302.000          0   0.527009 1953-11-01 2021-12-31
# DE02110      63.000          0  -1.123596 1951-11-01 2021-12-31
#
#           num_daily_obs  num_monthly  num_yearly
# basin_id
# ITVEN406           6157          204          18
# ITVEN407           6918          228          19
# ITVEN408           6918          228          19
# ITVEN409           6918          228          19
# ITVEN410           2945           98           9
# ...                 ...          ...         ...
# DE02106           21976          722          61
# DE02107           25629          842          71
# DE02108           23437          770          65
# DE02109           24891          818          69
# DE02110           25629          842          71
#
# [15046 rows x 18 columns]

# %%
# Calculate the number of gaps:
network_EU_net["num_days_gaps"] = ((network_EU_net['end_date'] - network_EU_net['start_date']).dt.days + 1) - network_EU_net['num_daily_obs']
network_EU_net
# Out:
#             gauge_id                 gauge_name      river        lon  \
# basin_id
# ITVEN406       270VE            Adige a Albaredo     Adige  11.266291
# ITVEN407       283VE           Brenta a Barzizza    Brenta  11.730543
# ITVEN408       284VE        Adige a Boara Pisani     Adige  11.784244
# ITVEN409       285VE  Tesina a Bolzano Vicentino    Tesina  11.620895
# ITVEN410       286VE    Frassine a Borgofrassine  Frassine  11.481112
# ...              ...                         ...       ...        ...
# DE02106   5752400000                  Hachelbich    Wipper  10.973000
# DE02107   5752500000                 Bleicherode      Bode  10.593000
# DE02108   5754000000                  Sundhausen     Helme  10.810000
# DE02109   5755000000                  Nordhausen     Zorge  10.784000
# DE02110   5756600000                      Ilfeld      Bere  10.786000
#
#                 lat      lon_r      lat_r   area_r elevation country  \
# basin_id
# ITVEN406  45.317948  11.266291  45.317948  11954.0     23.59      IT
# ITVEN407  45.777415  11.730543  45.777415   1567.0    105.38      IT
# ITVEN408  45.105481  11.784244  45.105481  11954.0       8.4      IT
# ITVEN409  45.600894  11.620895  45.600894    694.0     37.57      IT
# ITVEN410  45.251409  11.481112  45.251409      NaN     16.69      IT
# ...             ...        ...        ...      ...       ...     ...
# DE02106   51.347000  10.973000  51.347000    524.0       NaN      DE
# DE02107   51.450000  10.593000  51.450000    104.0       NaN      DE
# DE02108   51.468000  10.810000  51.468000    200.6       NaN      DE
# DE02109   51.507000  10.784000  51.507000    303.6       NaN      DE
# DE02110   51.598000  10.786000  51.598000     62.3       NaN      DE
#
#              area_c  area_flag  area_perc start_date   end_date  \
# basin_id
# ITVEN406  11938.762          0   0.127472 2005-07-07 2022-12-31
# ITVEN407   1571.329          0  -0.276260 2004-01-01 2022-12-31
# ITVEN408  12020.860          0  -0.559311 2004-01-01 2022-12-31
# ITVEN409    759.659          0  -9.460951 2004-01-01 2022-12-31
# ITVEN410    414.418          2        NaN 2012-11-11 2020-12-31
# ...             ...        ...        ...        ...        ...
# DE02106     524.000          0   0.000000 1961-11-01 2021-12-31
# DE02107     104.000          0   0.000000 1951-11-01 2021-12-31
# DE02108     200.000          0   0.299103 1957-11-01 2021-12-31
# DE02109     302.000          0   0.527009 1953-11-01 2021-12-31
# DE02110      63.000          0  -1.123596 1951-11-01 2021-12-31
#
#           num_daily_obs  num_monthly  num_yearly  num_days_gaps
# basin_id
# ITVEN406           6157          204          18          230.0
# ITVEN407           6918          228          19           22.0
# ITVEN408           6918          228          19           22.0
# ITVEN409           6918          228          19           22.0
# ITVEN410           2945           98           9           28.0
# ...                 ...          ...         ...            ...
# DE02106           21976          722          61            0.0
# DE02107           25629          842          71            0.0
# DE02108           23437          770          65            0.0
# DE02109           24891          818          69            7.0
# DE02110           25629          842          71            0.0
#
# [15046 rows x 19 columns]

# %%
# Here we compute the longest period with continuous measurements:
longest_gap_periods = longest_continuous_period(timeseries = timeseries_EU)
# Out:
# 100%|█████████████████████████████████████| 15046/15046 [02:48<00:00, 89.56it/s]

# %%
network_EU_net[["num_continuous_days"]] = longest_gap_periods

# %%
# Here we sort the index:
network_EU_net = network_EU_net.sort_index(axis=0)
network_EU_net
# Out:
#          gauge_id          gauge_name       river        lon        lat  \
# basin_id
# AT00001    200014                Bangs      Rhein   9.534835  47.273748
# AT00002    200048  Schruns (Vonbunweg)       Litz   9.913677  47.080301
# AT00003    231662        Loruens-Aeule        Ill   9.847765  47.132821
# AT00004    200592    Kloesterle (OEBB)     Alfenz  10.061843  47.128994
# AT00005    200097  Buers (Bruecke L82)     Alvier   9.802668  47.150770
# ...           ...                  ...        ...        ...        ...
# UAGR017   6682300          BASHTANOVKA      KACHA  33.894739  44.691884
# UAGR018   6682500                YALTA  DERE-KIOY  34.166667  44.500000
# UAGR019   6683010           PIONERSKOE     SALHYR  34.199841  44.887685
# UAGR020   6683200               TOKMAK     TOKMAK  35.705833  47.251389
# UAGR021   6683300          NOVOSELOVKA     KRYNKA  38.144722  48.153333
#
#               lon_r      lat_r  area_r elevation country    area_c  area_flag  \
# basin_id
# AT00001    9.534835  47.273748  4647.9       420      AT  4668.379          0
# AT00002    9.913677  47.080301   102.0       673      AT   102.287          0
# AT00003    9.847765  47.132821   535.2       579      AT   536.299          0
# AT00004   10.061843  47.128994    66.6      1014      AT    66.286          0
# AT00005    9.802668  47.150770    72.2       564      AT    72.448          0
# ...             ...        ...     ...       ...     ...       ...        ...
# UAGR017   33.900000  44.683333   321.0       NaN      UA   325.370          0
# UAGR018   34.166667  44.500000    49.7        16      UA    47.594          0
# UAGR019   34.200000  44.883333   261.0       307      UA   244.731          1
# UAGR020   35.705833  47.251389   760.0       NaN      UA   731.073          0
# UAGR021   38.144722  48.153333   582.0       118      UA   599.600          0
#
#           area_perc start_date   end_date  num_daily_obs  num_monthly  \
# basin_id
# AT00001   -0.440608 1996-01-01 2019-12-31           8766          288
# AT00002   -0.281373 1958-10-01 2019-12-31          22372          735
# AT00003   -0.205344 1985-01-02 2019-12-31          12782          420
# AT00004    0.471471 1998-01-02 2019-12-31           8034          264
# AT00005   -0.343490 1990-01-01 2019-12-31          10957          360
# ...             ...        ...        ...            ...          ...
# UAGR017   -1.361371 1978-01-01 1987-12-31           3652          120
# UAGR018    4.237425 1978-01-01 1987-12-31           3652          120
# UAGR019    6.233333 1978-01-01 1987-12-31           3652          120
# UAGR020    3.806184 1978-01-01 1987-12-31           3652          120
# UAGR021   -3.024055 1978-01-01 1987-12-31           3652          120
#
#           num_yearly  num_days_gaps num_continuous_days
# basin_id
# AT00001           24            0.0                8766
# AT00002           62            0.0               22372
# AT00003           35            0.0               12782
# AT00004           22            0.0                8034
# AT00005           30            0.0               10957
# ...              ...            ...                 ...
# UAGR017           10            0.0                3652
# UAGR018           10            0.0                3652
# UAGR019           10            0.0                3652
# UAGR020           10            0.0                3652
# UAGR021           10            0.0                3652
#
# [15046 rows x 20 columns]

# %%
network_EU_net.columns
# Out:
# Index(['gauge_id', 'gauge_name ', 'river', 'lon', 'lat', 'lon_r', 'lat_r',
#        'area_r', 'elevation', 'country', 'area_c', 'area_flag', 'area_perc',
#        'start_date', 'end_date', 'num_daily_obs', 'num_monthly', 'num_yearly',
#        'num_days_gaps', 'num_continuous_days'],
#       dtype='object')

# %%
network_EU_net.columns = ['gauge_id', 'gauge_name ', 'river', 'lon', 'lat', 'lon_r', 'lat_r',
                          'area_r', 'elevation', 'gauge_country', 'area_c', 'area_flag', 'area_perc',
                          'start_date', 'end_date', 'num_days', 'num_months', 'num_years',
                          'num_days_gaps', 'num_continuous_days']

network_EU_net = network_EU_net[['gauge_id', 'gauge_name ', 'gauge_country', 'river', 'lon', 'lat', 'lon_r', 'lat_r',
                          'area_r', 'elevation', 'area_c', 'area_flag', 'area_perc',
                          'start_date', 'end_date', 'num_years', 'num_months', 'num_days',
                          'num_days_gaps', 'num_continuous_days']]

network_EU_net
# Out:
#          gauge_id          gauge_name  gauge_country      river        lon  \
# basin_id
# AT00001    200014                Bangs            AT      Rhein   9.534835
# AT00002    200048  Schruns (Vonbunweg)            AT       Litz   9.913677
# AT00003    231662        Loruens-Aeule            AT        Ill   9.847765
# AT00004    200592    Kloesterle (OEBB)            AT     Alfenz  10.061843
# AT00005    200097  Buers (Bruecke L82)            AT     Alvier   9.802668
# ...           ...                  ...           ...        ...        ...
# UAGR017   6682300          BASHTANOVKA            UA      KACHA  33.894739
# UAGR018   6682500                YALTA            UA  DERE-KIOY  34.166667
# UAGR019   6683010           PIONERSKOE            UA     SALHYR  34.199841
# UAGR020   6683200               TOKMAK            UA     TOKMAK  35.705833
# UAGR021   6683300          NOVOSELOVKA            UA     KRYNKA  38.144722
#
#                 lat      lon_r      lat_r  area_r elevation    area_c  \
# basin_id
# AT00001   47.273748   9.534835  47.273748  4647.9       420  4668.379
# AT00002   47.080301   9.913677  47.080301   102.0       673   102.287
# AT00003   47.132821   9.847765  47.132821   535.2       579   536.299
# AT00004   47.128994  10.061843  47.128994    66.6      1014    66.286
# AT00005   47.150770   9.802668  47.150770    72.2       564    72.448
# ...             ...        ...        ...     ...       ...       ...
# UAGR017   44.691884  33.900000  44.683333   321.0       NaN   325.370
# UAGR018   44.500000  34.166667  44.500000    49.7        16    47.594
# UAGR019   44.887685  34.200000  44.883333   261.0       307   244.731
# UAGR020   47.251389  35.705833  47.251389   760.0       NaN   731.073
# UAGR021   48.153333  38.144722  48.153333   582.0       118   599.600
#
#           area_flag  area_perc start_date   end_date  num_years  num_months  \
# basin_id
# AT00001           0  -0.440608 1996-01-01 2019-12-31         24         288
# AT00002           0  -0.281373 1958-10-01 2019-12-31         62         735
# AT00003           0  -0.205344 1985-01-02 2019-12-31         35         420
# AT00004           0   0.471471 1998-01-02 2019-12-31         22         264
# AT00005           0  -0.343490 1990-01-01 2019-12-31         30         360
# ...             ...        ...        ...        ...        ...         ...
# UAGR017           0  -1.361371 1978-01-01 1987-12-31         10         120
# UAGR018           0   4.237425 1978-01-01 1987-12-31         10         120
# UAGR019           1   6.233333 1978-01-01 1987-12-31         10         120
# UAGR020           0   3.806184 1978-01-01 1987-12-31         10         120
# UAGR021           0  -3.024055 1978-01-01 1987-12-31         10         120
#
#           num_days  num_days_gaps num_continuous_days
# basin_id
# AT00001       8766            0.0                8766
# AT00002      22372            0.0               22372
# AT00003      12782            0.0               12782
# AT00004       8034            0.0                8034
# AT00005      10957            0.0               10957
# ...            ...            ...                 ...
# UAGR017       3652            0.0                3652
# UAGR018       3652            0.0                3652
# UAGR019       3652            0.0                3652
# UAGR020       3652            0.0                3652
# UAGR021       3652            0.0                3652
#
# [15046 rows x 20 columns]

# %% [markdown]
# ## New codes' definition:

# %%
# Adjust of the German names (inclusion of the region)
network_EU_net["region"] = network_EU.set_index("new_code", inplace = False)["region"]
network_EU_net[network_EU_net.gauge_country == "DE"]
# Out:
#             gauge_id                gauge_name  gauge_country  \
# basin_id
# DE00001      5891200    Alt Ruppin, Schleuse OP            DE
# DE00002      5871600         Babelsberg-Drewitz            DE
# DE00003      5530500            Bad Liebenwerda            DE
# DE00004      5930500               Bad Wilsnack            DE
# DE00005      5825500  Beeskow, Spreeschleuse UP            DE
# ...              ...                        ...           ...
# DE02106   5752400000                 Hachelbich            DE
# DE02107   5752500000                Bleicherode            DE
# DE02108   5754000000                 Sundhausen            DE
# DE02109   5755000000                 Nordhausen            DE
# DE02110   5756600000                     Ilfeld            DE
#
#                     river        lon        lat      lon_r      lat_r  \
# basin_id
# DE00001              Rhin  12.835157  52.959469  12.835157  52.959469
# DE00002             Nuthe  13.116304  52.362773  13.116304  52.362773
# DE00003   Schwarze Elster  13.394420  51.519043  13.394420  51.519043
# DE00004          Karthane  11.937284  52.956437  11.937284  52.956437
# DE00005             Spree  14.254694  52.171976  14.254694  52.171976
# ...                   ...        ...        ...        ...        ...
# DE02106            Wipper  10.973000  51.347000  10.973000  51.347000
# DE02107              Bode  10.593000  51.450000  10.593000  51.450000
# DE02108             Helme  10.810000  51.468000  10.810000  51.468000
# DE02109             Zorge  10.784000  51.507000  10.784000  51.507000
# DE02110              Bere  10.786000  51.598000  10.786000  51.598000
#
#                area_r elevation  ...  area_flag   area_perc  start_date  \
# basin_id                         ...
# DE00001    534.785653       NaN  ...          3 -134.602591  1980-11-01
# DE00002   1768.326729       NaN  ...          0   -1.485940  1954-11-01
# DE00003   3137.028384       NaN  ...          3   26.821510  1960-11-01
# DE00004    284.617208       NaN  ...          0   -1.609808  1975-11-01
# DE00005   5565.936643       NaN  ...          0    3.436989  1950-03-02
# ...               ...       ...  ...        ...         ...         ...
# DE02106    524.000000       NaN  ...          0    0.000000  1961-11-01
# DE02107    104.000000       NaN  ...          0    0.000000  1951-11-01
# DE02108    200.600000       NaN  ...          0    0.299103  1957-11-01
# DE02109    303.600000       NaN  ...          0    0.527009  1953-11-01
# DE02110     62.300000       NaN  ...          0   -1.123596  1951-11-01
#
#            end_date num_years  num_months  num_days  num_days_gaps  \
# basin_id
# DE00001  2023-09-25        44         515     15669            0.0
# DE00002  2023-09-24        70         827     25160            5.0
# DE00003  2023-09-18        64         755     22967            0.0
# DE00004  2023-09-24        47         539     16399         1096.0
# DE00005  2023-09-19        74         883     26865            0.0
# ...             ...       ...         ...       ...            ...
# DE02106  2021-12-31        61         722     21976            0.0
# DE02107  2021-12-31        71         842     25629            0.0
# DE02108  2021-12-31        65         770     23437            0.0
# DE02109  2021-12-31        69         818     24891            7.0
# DE02110  2021-12-31        71         842     25629            0.0
#
#           num_continuous_days region
# basin_id
# DE00001                 15669     BB
# DE00002                 25124     BB
# DE00003                 22967     BB
# DE00004                 14938     BB
# DE00005                 26865     BB
# ...                       ...    ...
# DE02106                 21976     TH
# DE02107                 25629     TH
# DE02108                 23437     TH
# DE02109                 24650     TH
# DE02110                 25629     TH
#
# [2095 rows x 21 columns]

# %%
#create a old code column
network_EU_net['old_code'] = network_EU_net.index

# Extract the first four digits from the 'old_code' column
network_EU_net['first_four_digits'] = network_EU_net['old_code'].str.extract('([A-Za-z]{1,4})')

# Add zeros to ensure a total length of 4 characters
network_EU_net['first_four_digits'] = network_EU_net['first_four_digits'].apply(lambda x: x.ljust(4, '0'))

# Extract the numeric part from the 'code' column
network_EU_net['numeric_part'] = network_EU_net.old_code.str.extract('(\d+)')

# Convert 'numeric_part' to a 4-digit string with leading zeros
network_EU_net['numeric_part'] = network_EU_net['numeric_part'].apply(lambda x: f"{int(x):04d}")

## Create a new column 'new_code' by concatenating 'region' and 'numeric_part'
network_EU_net['new_code'] = network_EU_net['first_four_digits'] + network_EU_net['numeric_part']

network_EU_net
# Out:
#          gauge_id          gauge_name  gauge_country      river        lon  \
# basin_id
# AT00001    200014                Bangs            AT      Rhein   9.534835
# AT00002    200048  Schruns (Vonbunweg)            AT       Litz   9.913677
# AT00003    231662        Loruens-Aeule            AT        Ill   9.847765
# AT00004    200592    Kloesterle (OEBB)            AT     Alfenz  10.061843
# AT00005    200097  Buers (Bruecke L82)            AT     Alvier   9.802668
# ...           ...                  ...           ...        ...        ...
# UAGR017   6682300          BASHTANOVKA            UA      KACHA  33.894739
# UAGR018   6682500                YALTA            UA  DERE-KIOY  34.166667
# UAGR019   6683010           PIONERSKOE            UA     SALHYR  34.199841
# UAGR020   6683200               TOKMAK            UA     TOKMAK  35.705833
# UAGR021   6683300          NOVOSELOVKA            UA     KRYNKA  38.144722
#
#                 lat      lon_r      lat_r  area_r elevation  ...  num_years  \
# basin_id                                                     ...
# AT00001   47.273748   9.534835  47.273748  4647.9       420  ...         24
# AT00002   47.080301   9.913677  47.080301   102.0       673  ...         62
# AT00003   47.132821   9.847765  47.132821   535.2       579  ...         35
# AT00004   47.128994  10.061843  47.128994    66.6      1014  ...         22
# AT00005   47.150770   9.802668  47.150770    72.2       564  ...         30
# ...             ...        ...        ...     ...       ...  ...        ...
# UAGR017   44.691884  33.900000  44.683333   321.0       NaN  ...         10
# UAGR018   44.500000  34.166667  44.500000    49.7        16  ...         10
# UAGR019   44.887685  34.200000  44.883333   261.0       307  ...         10
# UAGR020   47.251389  35.705833  47.251389   760.0       NaN  ...         10
# UAGR021   48.153333  38.144722  48.153333   582.0       118  ...         10
#
#           num_months  num_days num_days_gaps num_continuous_days  region  \
# basin_id
# AT00001          288      8766           0.0                8766     NaN
# AT00002          735     22372           0.0               22372     NaN
# AT00003          420     12782           0.0               12782     NaN
# AT00004          264      8034           0.0                8034     NaN
# AT00005          360     10957           0.0               10957     NaN
# ...              ...       ...           ...                 ...     ...
# UAGR017          120      3652           0.0                3652     NaN
# UAGR018          120      3652           0.0                3652     NaN
# UAGR019          120      3652           0.0                3652     NaN
# UAGR020          120      3652           0.0                3652     NaN
# UAGR021          120      3652           0.0                3652     NaN
#
#           old_code  first_four_digits  numeric_part  new_code
# basin_id
# AT00001    AT00001               AT00          0001  AT000001
# AT00002    AT00002               AT00          0002  AT000002
# AT00003    AT00003               AT00          0003  AT000003
# AT00004    AT00004               AT00          0004  AT000004
# AT00005    AT00005               AT00          0005  AT000005
# ...            ...                ...           ...       ...
# UAGR017    UAGR017               UAGR          0017  UAGR0017
# UAGR018    UAGR018               UAGR          0018  UAGR0018
# UAGR019    UAGR019               UAGR          0019  UAGR0019
# UAGR020    UAGR020               UAGR          0020  UAGR0020
# UAGR021    UAGR021               UAGR          0021  UAGR0021
#
# [15046 rows x 25 columns]

# %%
# Here we can check it:
network_EU_net[network_EU_net.gauge_country == "IT"]
# Out:
#                           gauge_id                     gauge_name   \
# basin_id
# ITABR441           Aterno a Molina                 Aterno a Molina
# ITABR442        Aterno a Tre Ponti              Aterno a Tre Ponti
# ITABR443       Feltrino a San Vito             Feltrino a San Vito
# ITABR444         Pescara a Maraone               Pescara a Maraone
# ITABR445  Sagittario a Capo Canale        Sagittario a Capo Canale
# ...                            ...                             ...
# ITVEN436                     271VE  Piave a Belluno Ponte Vittoria
# ITVEN437                     277VE           Cordevole a Ponte Mas
# ITVEN438                     327VE                Piave a Segusino
# ITVEN439                     374VE                  Brenta a Enego
# ITVEN440                     557VE       Piave a Belluno unificata
#
#          gauge_country       river        lon        lat      lon_r  \
# basin_id
# ITABR441            IT      Aterno  13.753056  42.137222  13.753056
# ITABR442            IT      Aterno  13.258056  42.476389  13.258056
# ITABR443            IT    Feltrino  14.439444  42.296389  14.439444
# ITABR444            IT     Pescara  13.838611  42.180000  13.838611
# ITABR445            IT  Sagittario  13.866389  42.123333  13.866389
# ...                ...         ...        ...        ...        ...
# ITVEN436            IT       Piave  12.218586  46.134222  12.218586
# ITVEN437            IT   Cordevole  12.125220  46.154313  12.125220
# ITVEN438            IT       Piave  11.948837  45.922490  11.948837
# ITVEN439            IT      Brenta  11.715000  45.954413  11.715000
# ITVEN440            IT       Piave  12.228124  46.127896  12.228124
#
#               lat_r  area_r elevation  ...  num_years  num_months  num_days  \
# basin_id                               ...
# ITABR441  42.137222  1303.0       454  ...         10         114      3454
# ITABR442  42.476389   114.0       774  ...         10         113      3250
# ITABR443  42.296389    50.0        24  ...         10         114      3411
# ITABR444  42.180000  2003.0       246  ...         10         114      3455
# ITABR445  42.123333   599.0       275  ...         10         114      3456
# ...             ...     ...       ...  ...        ...         ...       ...
# ITVEN436  46.134222     NaN       NaN  ...          3          30       826
# ITVEN437  46.154313   696.0    360.75  ...         21         213      6032
# ITVEN438  45.922490  3469.0    177.39  ...         19         216      6284
# ITVEN439  45.954413   646.0       NaN  ...         18         204      6062
# ITVEN440  46.127896  1980.0    329.29  ...          5          54      1615
#
#          num_days_gaps num_continuous_days  region  old_code  \
# basin_id
# ITABR441           8.0                1954     NaN  ITABR441
# ITABR442         212.0                 620     NaN  ITABR442
# ITABR443          51.0                 937     NaN  ITABR443
# ITABR444           7.0                1723     NaN  ITABR444
# ITABR445           6.0                2189     NaN  ITABR445
# ...                ...                 ...     ...       ...
# ITVEN436         134.0                 422     NaN  ITVEN436
# ITVEN437        1308.0                2121     NaN  ITVEN437
# ITVEN438         656.0                2041     NaN  ITVEN438
# ITVEN439         171.0                2384     NaN  ITVEN439
# ITVEN440           2.0                1614     NaN  ITVEN440
#
#           first_four_digits  numeric_part  new_code
# basin_id
# ITABR441               ITAB          0441  ITAB0441
# ITABR442               ITAB          0442  ITAB0442
# ITABR443               ITAB          0443  ITAB0443
# ITABR444               ITAB          0444  ITAB0444
# ITABR445               ITAB          0445  ITAB0445
# ...                     ...           ...       ...
# ITVEN436               ITVE          0436  ITVE0436
# ITVEN437               ITVE          0437  ITVE0437
# ITVEN438               ITVE          0438  ITVE0438
# ITVEN439               ITVE          0439  ITVE0439
# ITVEN440               ITVE          0440  ITVE0440
#
# [767 rows x 25 columns]

# %% [markdown]
# * ### Germany

# %%
# Subset only germany
network_EU_net_DE = network_EU_net[network_EU_net.gauge_country == "DE"]

# Extract the numeric part from the 'code' column
network_EU_net_DE['numeric_part'] = network_EU_net_DE.old_code.str.extract('(\d+)')

# Convert 'numeric_part' to a 4-digit string with leading zeros
network_EU_net_DE['numeric_part'] = network_EU_net_DE['numeric_part'].apply(lambda x: f"{int(x):04d}")

## Create a new column 'new_code' by concatenating 'region' and 'numeric_part'
network_EU_net_DE['new_code'] = "DE" + network_EU_net_DE['region'] + network_EU_net_DE['numeric_part']

network_EU_net_DE
# Out:
#             gauge_id                gauge_name  gauge_country  \
# basin_id
# DE00001      5891200    Alt Ruppin, Schleuse OP            DE
# DE00002      5871600         Babelsberg-Drewitz            DE
# DE00003      5530500            Bad Liebenwerda            DE
# DE00004      5930500               Bad Wilsnack            DE
# DE00005      5825500  Beeskow, Spreeschleuse UP            DE
# ...              ...                        ...           ...
# DE02106   5752400000                 Hachelbich            DE
# DE02107   5752500000                Bleicherode            DE
# DE02108   5754000000                 Sundhausen            DE
# DE02109   5755000000                 Nordhausen            DE
# DE02110   5756600000                     Ilfeld            DE
#
#                     river        lon        lat      lon_r      lat_r  \
# basin_id
# DE00001              Rhin  12.835157  52.959469  12.835157  52.959469
# DE00002             Nuthe  13.116304  52.362773  13.116304  52.362773
# DE00003   Schwarze Elster  13.394420  51.519043  13.394420  51.519043
# DE00004          Karthane  11.937284  52.956437  11.937284  52.956437
# DE00005             Spree  14.254694  52.171976  14.254694  52.171976
# ...                   ...        ...        ...        ...        ...
# DE02106            Wipper  10.973000  51.347000  10.973000  51.347000
# DE02107              Bode  10.593000  51.450000  10.593000  51.450000
# DE02108             Helme  10.810000  51.468000  10.810000  51.468000
# DE02109             Zorge  10.784000  51.507000  10.784000  51.507000
# DE02110              Bere  10.786000  51.598000  10.786000  51.598000
#
#                area_r elevation  ...  num_years  num_months  num_days  \
# basin_id                         ...
# DE00001    534.785653       NaN  ...         44         515     15669
# DE00002   1768.326729       NaN  ...         70         827     25160
# DE00003   3137.028384       NaN  ...         64         755     22967
# DE00004    284.617208       NaN  ...         47         539     16399
# DE00005   5565.936643       NaN  ...         74         883     26865
# ...               ...       ...  ...        ...         ...       ...
# DE02106    524.000000       NaN  ...         61         722     21976
# DE02107    104.000000       NaN  ...         71         842     25629
# DE02108    200.600000       NaN  ...         65         770     23437
# DE02109    303.600000       NaN  ...         69         818     24891
# DE02110     62.300000       NaN  ...         71         842     25629
#
#          num_days_gaps num_continuous_days  region  old_code  \
# basin_id
# DE00001            0.0               15669      BB   DE00001
# DE00002            5.0               25124      BB   DE00002
# DE00003            0.0               22967      BB   DE00003
# DE00004         1096.0               14938      BB   DE00004
# DE00005            0.0               26865      BB   DE00005
# ...                ...                 ...     ...       ...
# DE02106            0.0               21976      TH   DE02106
# DE02107            0.0               25629      TH   DE02107
# DE02108            0.0               23437      TH   DE02108
# DE02109            7.0               24650      TH   DE02109
# DE02110            0.0               25629      TH   DE02110
#
#           first_four_digits  numeric_part  new_code
# basin_id
# DE00001                DE00          0001  DEBB0001
# DE00002                DE00          0002  DEBB0002
# DE00003                DE00          0003  DEBB0003
# DE00004                DE00          0004  DEBB0004
# DE00005                DE00          0005  DEBB0005
# ...                     ...           ...       ...
# DE02106                DE00          2106  DETH2106
# DE02107                DE00          2107  DETH2107
# DE02108                DE00          2108  DETH2108
# DE02109                DE00          2109  DETH2109
# DE02110                DE00          2110  DETH2110
#
# [2095 rows x 25 columns]

# %%
# here we replace only for Germany and check the results:
network_EU_net.loc[network_EU_net_DE.index, "new_code"] = network_EU_net_DE['new_code']
network_EU_net[network_EU_net.gauge_country == "DE"]
# Out:
#             gauge_id                gauge_name  gauge_country  \
# basin_id
# DE00001      5891200    Alt Ruppin, Schleuse OP            DE
# DE00002      5871600         Babelsberg-Drewitz            DE
# DE00003      5530500            Bad Liebenwerda            DE
# DE00004      5930500               Bad Wilsnack            DE
# DE00005      5825500  Beeskow, Spreeschleuse UP            DE
# ...              ...                        ...           ...
# DE02106   5752400000                 Hachelbich            DE
# DE02107   5752500000                Bleicherode            DE
# DE02108   5754000000                 Sundhausen            DE
# DE02109   5755000000                 Nordhausen            DE
# DE02110   5756600000                     Ilfeld            DE
#
#                     river        lon        lat      lon_r      lat_r  \
# basin_id
# DE00001              Rhin  12.835157  52.959469  12.835157  52.959469
# DE00002             Nuthe  13.116304  52.362773  13.116304  52.362773
# DE00003   Schwarze Elster  13.394420  51.519043  13.394420  51.519043
# DE00004          Karthane  11.937284  52.956437  11.937284  52.956437
# DE00005             Spree  14.254694  52.171976  14.254694  52.171976
# ...                   ...        ...        ...        ...        ...
# DE02106            Wipper  10.973000  51.347000  10.973000  51.347000
# DE02107              Bode  10.593000  51.450000  10.593000  51.450000
# DE02108             Helme  10.810000  51.468000  10.810000  51.468000
# DE02109             Zorge  10.784000  51.507000  10.784000  51.507000
# DE02110              Bere  10.786000  51.598000  10.786000  51.598000
#
#                area_r elevation  ...  num_years  num_months  num_days  \
# basin_id                         ...
# DE00001    534.785653       NaN  ...         44         515     15669
# DE00002   1768.326729       NaN  ...         70         827     25160
# DE00003   3137.028384       NaN  ...         64         755     22967
# DE00004    284.617208       NaN  ...         47         539     16399
# DE00005   5565.936643       NaN  ...         74         883     26865
# ...               ...       ...  ...        ...         ...       ...
# DE02106    524.000000       NaN  ...         61         722     21976
# DE02107    104.000000       NaN  ...         71         842     25629
# DE02108    200.600000       NaN  ...         65         770     23437
# DE02109    303.600000       NaN  ...         69         818     24891
# DE02110     62.300000       NaN  ...         71         842     25629
#
#          num_days_gaps num_continuous_days  region  old_code  \
# basin_id
# DE00001            0.0               15669      BB   DE00001
# DE00002            5.0               25124      BB   DE00002
# DE00003            0.0               22967      BB   DE00003
# DE00004         1096.0               14938      BB   DE00004
# DE00005            0.0               26865      BB   DE00005
# ...                ...                 ...     ...       ...
# DE02106            0.0               21976      TH   DE02106
# DE02107            0.0               25629      TH   DE02107
# DE02108            0.0               23437      TH   DE02108
# DE02109            7.0               24650      TH   DE02109
# DE02110            0.0               25629      TH   DE02110
#
#           first_four_digits  numeric_part  new_code
# basin_id
# DE00001                DE00          0001  DEBB0001
# DE00002                DE00          0002  DEBB0002
# DE00003                DE00          0003  DEBB0003
# DE00004                DE00          0004  DEBB0004
# DE00005                DE00          0005  DEBB0005
# ...                     ...           ...       ...
# DE02106                DE00          2106  DETH2106
# DE02107                DE00          2107  DETH2107
# DE02108                DE00          2108  DETH2108
# DE02109                DE00          2109  DETH2109
# DE02110                DE00          2110  DETH2110
#
# [2095 rows x 25 columns]

# %% [markdown]
# * ### Belgium

# %%
# Subset only Belgium
network_EU_net_BE = network_EU_net[network_EU_net.gauge_country == "BE"]

## Create a new column 'new_code' by concatenating 'region' and 'numeric_part'
network_EU_net_BE['new_code'] = "BE" + network_EU_net_BE['region'] + network_EU_net_BE['numeric_part']

network_EU_net_BE
# Out:
#             gauge_id  gauge_name  gauge_country             river       lon  \
# basin_id
# BE00001     10461002      Bierges            BE              Dyle  4.606129
# BE00002     19511002       Tubize            BE             Senne  4.196446
# BE00003     23711002   Ronquieres            BE             Samme  4.224809
# BE00004     29521002   Irchonwelz            BE   DendreOrientale  3.751661
# BE00005     29711002          Ath            BE   DendreOrientale  3.777834
# ...              ...          ...           ...               ...       ...
# BE00226    01L07_287       Ternat            BE   Steenvoordebeek  4.176000
# BE00227    01L07_289        Viane            BE              Mark  3.892000
# BE00228    01L01_493  Vlamertinge            BE  Grote Kemmelbeek  2.811000
# BE00229   01LS09_165       Wellen            BE              Herk  5.326000
# BE00230    01L09_143     Wezemaal            BE     Grote Losting  4.744000
#
#                 lat     lon_r      lat_r  area_r elevation  ...  num_years  \
# basin_id                                                    ...
# BE00001   50.710583  4.606129  50.710583   310.0       NaN  ...         47
# BE00002   50.690256  4.196446  50.690256   215.0       NaN  ...         24
# BE00003   50.605923  4.224809  50.605923   135.0       NaN  ...         33
# BE00004   50.618903  3.751661  50.618903   126.0       NaN  ...         44
# BE00005   50.633521  3.777834  50.633521   229.0       NaN  ...         45
# ...             ...       ...        ...     ...       ...  ...        ...
# BE00226   50.876000  4.176000  50.876000     NaN       NaN  ...         40
# BE00227   50.741000  3.892000  50.741000     NaN       NaN  ...         48
# BE00228   50.844000  2.811000  50.844000     NaN       NaN  ...         41
# BE00229   50.850000  5.326000  50.850000     NaN       NaN  ...         52
# BE00230   50.943000  4.744000  50.943000     NaN       NaN  ...         38
#
#           num_months  num_days num_days_gaps num_continuous_days  region  \
# basin_id
# BE00001          564     17162           5.0               15955      WA
# BE00002          288      8766           0.0                8766      WA
# BE00003          396     12053           0.0               12053      WA
# BE00004          528     16071           0.0               16071      WA
# BE00005          540     16436           0.0               16436      WA
# ...              ...       ...           ...                 ...     ...
# BE00226          454     13456        1314.0                3758      VL
# BE00227          556     16430         700.0                1905      VL
# BE00228          475     13350        2416.0                9860      VL
# BE00229          593     17571        1291.0                3603      VL
# BE00230          443     13263         261.0                2036      VL
#
#           old_code  first_four_digits  numeric_part  new_code
# basin_id
# BE00001    BE00001               BE00          0001  BEWA0001
# BE00002    BE00002               BE00          0002  BEWA0002
# BE00003    BE00003               BE00          0003  BEWA0003
# BE00004    BE00004               BE00          0004  BEWA0004
# BE00005    BE00005               BE00          0005  BEWA0005
# ...            ...                ...           ...       ...
# BE00226    BE00226               BE00          0226  BEVL0226
# BE00227    BE00227               BE00          0227  BEVL0227
# BE00228    BE00228               BE00          0228  BEVL0228
# BE00229    BE00229               BE00          0229  BEVL0229
# BE00230    BE00230               BE00          0230  BEVL0230
#
# [230 rows x 25 columns]

# %%
# here we replace only for Germany and check the results:
network_EU_net.loc[network_EU_net_BE.index, "new_code"] = network_EU_net_BE['new_code']
network_EU_net[network_EU_net.gauge_country == "BE"]
# Out:
#             gauge_id  gauge_name  gauge_country             river       lon  \
# basin_id
# BE00001     10461002      Bierges            BE              Dyle  4.606129
# BE00002     19511002       Tubize            BE             Senne  4.196446
# BE00003     23711002   Ronquieres            BE             Samme  4.224809
# BE00004     29521002   Irchonwelz            BE   DendreOrientale  3.751661
# BE00005     29711002          Ath            BE   DendreOrientale  3.777834
# ...              ...          ...           ...               ...       ...
# BE00226    01L07_287       Ternat            BE   Steenvoordebeek  4.176000
# BE00227    01L07_289        Viane            BE              Mark  3.892000
# BE00228    01L01_493  Vlamertinge            BE  Grote Kemmelbeek  2.811000
# BE00229   01LS09_165       Wellen            BE              Herk  5.326000
# BE00230    01L09_143     Wezemaal            BE     Grote Losting  4.744000
#
#                 lat     lon_r      lat_r  area_r elevation  ...  num_years  \
# basin_id                                                    ...
# BE00001   50.710583  4.606129  50.710583   310.0       NaN  ...         47
# BE00002   50.690256  4.196446  50.690256   215.0       NaN  ...         24
# BE00003   50.605923  4.224809  50.605923   135.0       NaN  ...         33
# BE00004   50.618903  3.751661  50.618903   126.0       NaN  ...         44
# BE00005   50.633521  3.777834  50.633521   229.0       NaN  ...         45
# ...             ...       ...        ...     ...       ...  ...        ...
# BE00226   50.876000  4.176000  50.876000     NaN       NaN  ...         40
# BE00227   50.741000  3.892000  50.741000     NaN       NaN  ...         48
# BE00228   50.844000  2.811000  50.844000     NaN       NaN  ...         41
# BE00229   50.850000  5.326000  50.850000     NaN       NaN  ...         52
# BE00230   50.943000  4.744000  50.943000     NaN       NaN  ...         38
#
#           num_months  num_days num_days_gaps num_continuous_days  region  \
# basin_id
# BE00001          564     17162           5.0               15955      WA
# BE00002          288      8766           0.0                8766      WA
# BE00003          396     12053           0.0               12053      WA
# BE00004          528     16071           0.0               16071      WA
# BE00005          540     16436           0.0               16436      WA
# ...              ...       ...           ...                 ...     ...
# BE00226          454     13456        1314.0                3758      VL
# BE00227          556     16430         700.0                1905      VL
# BE00228          475     13350        2416.0                9860      VL
# BE00229          593     17571        1291.0                3603      VL
# BE00230          443     13263         261.0                2036      VL
#
#           old_code  first_four_digits  numeric_part  new_code
# basin_id
# BE00001    BE00001               BE00          0001  BEWA0001
# BE00002    BE00002               BE00          0002  BEWA0002
# BE00003    BE00003               BE00          0003  BEWA0003
# BE00004    BE00004               BE00          0004  BEWA0004
# BE00005    BE00005               BE00          0005  BEWA0005
# ...            ...                ...           ...       ...
# BE00226    BE00226               BE00          0226  BEVL0226
# BE00227    BE00227               BE00          0227  BEVL0227
# BE00228    BE00228               BE00          0228  BEVL0228
# BE00229    BE00229               BE00          0229  BEVL0229
# BE00230    BE00230               BE00          0230  BEVL0230
#
# [230 rows x 25 columns]

# %% [markdown]
# * ## Final adjusts

# %%
network_EU_net.drop(["region", "first_four_digits", "numeric_part"], axis = 1, inplace = True)
network_EU_net
# Out:
#          gauge_id          gauge_name  gauge_country      river        lon  \
# basin_id
# AT00001    200014                Bangs            AT      Rhein   9.534835
# AT00002    200048  Schruns (Vonbunweg)            AT       Litz   9.913677
# AT00003    231662        Loruens-Aeule            AT        Ill   9.847765
# AT00004    200592    Kloesterle (OEBB)            AT     Alfenz  10.061843
# AT00005    200097  Buers (Bruecke L82)            AT     Alvier   9.802668
# ...           ...                  ...           ...        ...        ...
# UAGR017   6682300          BASHTANOVKA            UA      KACHA  33.894739
# UAGR018   6682500                YALTA            UA  DERE-KIOY  34.166667
# UAGR019   6683010           PIONERSKOE            UA     SALHYR  34.199841
# UAGR020   6683200               TOKMAK            UA     TOKMAK  35.705833
# UAGR021   6683300          NOVOSELOVKA            UA     KRYNKA  38.144722
#
#                 lat      lon_r      lat_r  area_r elevation  ...  area_perc  \
# basin_id                                                     ...
# AT00001   47.273748   9.534835  47.273748  4647.9       420  ...  -0.440608
# AT00002   47.080301   9.913677  47.080301   102.0       673  ...  -0.281373
# AT00003   47.132821   9.847765  47.132821   535.2       579  ...  -0.205344
# AT00004   47.128994  10.061843  47.128994    66.6      1014  ...   0.471471
# AT00005   47.150770   9.802668  47.150770    72.2       564  ...  -0.343490
# ...             ...        ...        ...     ...       ...  ...        ...
# UAGR017   44.691884  33.900000  44.683333   321.0       NaN  ...  -1.361371
# UAGR018   44.500000  34.166667  44.500000    49.7        16  ...   4.237425
# UAGR019   44.887685  34.200000  44.883333   261.0       307  ...   6.233333
# UAGR020   47.251389  35.705833  47.251389   760.0       NaN  ...   3.806184
# UAGR021   48.153333  38.144722  48.153333   582.0       118  ...  -3.024055
#
#           start_date   end_date num_years num_months  num_days  num_days_gaps  \
# basin_id
# AT00001   1996-01-01 2019-12-31        24        288      8766            0.0
# AT00002   1958-10-01 2019-12-31        62        735     22372            0.0
# AT00003   1985-01-02 2019-12-31        35        420     12782            0.0
# AT00004   1998-01-02 2019-12-31        22        264      8034            0.0
# AT00005   1990-01-01 2019-12-31        30        360     10957            0.0
# ...              ...        ...       ...        ...       ...            ...
# UAGR017   1978-01-01 1987-12-31        10        120      3652            0.0
# UAGR018   1978-01-01 1987-12-31        10        120      3652            0.0
# UAGR019   1978-01-01 1987-12-31        10        120      3652            0.0
# UAGR020   1978-01-01 1987-12-31        10        120      3652            0.0
# UAGR021   1978-01-01 1987-12-31        10        120      3652            0.0
#
#           num_continuous_days  old_code  new_code
# basin_id
# AT00001                  8766   AT00001  AT000001
# AT00002                 22372   AT00002  AT000002
# AT00003                 12782   AT00003  AT000003
# AT00004                  8034   AT00004  AT000004
# AT00005                 10957   AT00005  AT000005
# ...                       ...       ...       ...
# UAGR017                  3652   UAGR017  UAGR0017
# UAGR018                  3652   UAGR018  UAGR0018
# UAGR019                  3652   UAGR019  UAGR0019
# UAGR020                  3652   UAGR020  UAGR0020
# UAGR021                  3652   UAGR021  UAGR0021
#
# [15046 rows x 22 columns]

# %% [markdown]
# ## Add data provider

# %%
# Read the catalogue
estreams_streamflow_catalogue = pd.read_excel("data/streamflow/estreams_streamflow_catalogue.xlsx")
estreams_streamflow_catalogue
# Out:
#      provider_id code_basins        provider_country country_code  \
# 0        AT_EHYD          AT                 AUSTRIA           AU
# 1        BA_FHMZ          BA  Bosnia and Herzegovina           BO
# 2         BE_SPW        BEWA                 BELGIUM           BE
# 3   BE_WATERINFO        BEVL                 BELGIUM           BE
# 4        BG_GRDC        BGGR                BULGARIA           BG
# ..           ...         ...                     ...          ...
# 65       SE_SMHI          SE                  SWEDEN           SE
# 66       SI_ARSO          SI                SLOVENIA           SI
# 67       SK_GRDC        SKGR                SLOVAKIA           SK
# 68       TR_GRDC        TRGR                  TURKEY           TR
# 69       UA_GRDC        UAGR                 UKRAINE           UA
#
#                                         provider_name license_redistribution  \
# 0                    Hydrographie Oesterreichs (EHYD)                      -
# 1            Federalni Hidrometeoroloski Zavod (FHMZ)                      -
# 2                    Service public de Wallonie (SPW)      No-redistribution
# 3                               Vlaanderen waterinfo    Reproduction allowed
# 4                    Global Runoff Data Center (GRDC)      No-redistribution
# ..                                                ...                    ...
# 65  Swedish Meteorological and Hydrological Instit...              CC BY 4.0
# 66      Agencija Republike Slovenije za Okolje (ARSO)                      -
# 67                   Global Runoff Data Center (GRDC)      No-redistribution
# 68                   Global Runoff Data Center (GRDC)      No-redistribution
# 69                   Global Runoff Data Center (GRDC)      No-redistribution
#
#    platform  num_stations     boundaries source_license  \
# 0   Website           NaN      Available            NaN
# 1   Website           NaN  Not available            NaN
# 2   Website           NaN  Not available            NaN
# 3   Website           NaN  Not available            NaN
# 4   Website           NaN  Not available            NaN
# ..      ...           ...            ...            ...
# 65  Website           NaN  Not available            NaN
# 66  Website           NaN  Not available            NaN
# 67  Website           NaN  Not available            NaN
# 68  Website           NaN  Not available            NaN
# 69  Website           NaN  Not available            NaN
#
#                                     source_streamflow  \
# 0                                 https://ehyd.gv.at/
# 1   https://www.fhmzbih.gov.ba/latinica/HIDRO/godi...
# 2                     https://hydrometrie.wallonie.be
# 3     https://www.waterinfo.be/kaartencatalogus?KL=en
# 4                         https://www.bafg.de/GRDC/EN
# ..                                                ...
# 65                https://vattenweb.smhi.se/station/#
# 66                 https://vode.arso.gov.si/hidarhiv/
# 67                        https://www.bafg.de/GRDC/EN
# 68                        https://www.bafg.de/GRDC/EN
# 69                        https://www.bafg.de/GRDC/EN
#
#                                   source_gauges_infos  \
# 0      https://zenodo.org/record/5153305#.ZDUeaOZBwuU
# 1   https://www.fhmzbih.gov.ba/latinica/HIDRO/godi...
# 2                     https://hydrometrie.wallonie.be
# 3     https://www.waterinfo.be/kaartencatalogus?KL=en
# 4                         https://www.bafg.de/GRDC/EN
# ..                                                ...
# 65                https://vattenweb.smhi.se/station/#
# 66                 https://vode.arso.gov.si/hidarhiv/
# 67                        https://www.bafg.de/GRDC/EN
# 68                        https://www.bafg.de/GRDC/EN
# 69                        https://www.bafg.de/GRDC/EN
#
#                                  source_boundaries  references observations
# 0   https://zenodo.org/record/5153305#.ZDUeaOZBwuU         NaN          NaN
# 1                                                -         NaN          NaN
# 2                                                -         NaN          NaN
# 3                                                -         NaN          NaN
# 4                      https://www.bafg.de/GRDC/EN         NaN          NaN
# ..                                             ...         ...          ...
# 65                                               -         NaN          NaN
# 66                                               -         NaN          NaN
# 67                     https://www.bafg.de/GRDC/EN         NaN          NaN
# 68                     https://www.bafg.de/GRDC/EN         NaN          NaN
# 69                     https://www.bafg.de/GRDC/EN         NaN          NaN
#
# [70 rows x 15 columns]

# %%
# Assign the values for each gauge
network_EU_net["gauge_provider"] = np.nan

for code, provider_id in tqdm(zip(estreams_streamflow_catalogue.code_basins, estreams_streamflow_catalogue.provider_id)):
    network_EU_net_code = network_EU_net[network_EU_net.new_code.str.contains(code, case=False)]
    network_EU_net.loc[network_EU_net_code.index, "gauge_provider"] = provider_id
# Out:
# 70it [00:00, 291.11it/s]

# %%
network_EU_net
# Out:
#          gauge_id          gauge_name  gauge_country      river        lon  \
# basin_id
# AT00001    200014                Bangs            AT      Rhein   9.534835
# AT00002    200048  Schruns (Vonbunweg)            AT       Litz   9.913677
# AT00003    231662        Loruens-Aeule            AT        Ill   9.847765
# AT00004    200592    Kloesterle (OEBB)            AT     Alfenz  10.061843
# AT00005    200097  Buers (Bruecke L82)            AT     Alvier   9.802668
# ...           ...                  ...           ...        ...        ...
# UAGR017   6682300          BASHTANOVKA            UA      KACHA  33.894739
# UAGR018   6682500                YALTA            UA  DERE-KIOY  34.166667
# UAGR019   6683010           PIONERSKOE            UA     SALHYR  34.199841
# UAGR020   6683200               TOKMAK            UA     TOKMAK  35.705833
# UAGR021   6683300          NOVOSELOVKA            UA     KRYNKA  38.144722
#
#                 lat      lon_r      lat_r  area_r elevation  ...  start_date  \
# basin_id                                                     ...
# AT00001   47.273748   9.534835  47.273748  4647.9       420  ...  1996-01-01
# AT00002   47.080301   9.913677  47.080301   102.0       673  ...  1958-10-01
# AT00003   47.132821   9.847765  47.132821   535.2       579  ...  1985-01-02
# AT00004   47.128994  10.061843  47.128994    66.6      1014  ...  1998-01-02
# AT00005   47.150770   9.802668  47.150770    72.2       564  ...  1990-01-01
# ...             ...        ...        ...     ...       ...  ...         ...
# UAGR017   44.691884  33.900000  44.683333   321.0       NaN  ...  1978-01-01
# UAGR018   44.500000  34.166667  44.500000    49.7        16  ...  1978-01-01
# UAGR019   44.887685  34.200000  44.883333   261.0       307  ...  1978-01-01
# UAGR020   47.251389  35.705833  47.251389   760.0       NaN  ...  1978-01-01
# UAGR021   48.153333  38.144722  48.153333   582.0       118  ...  1978-01-01
#
#            end_date  num_years num_months num_days  num_days_gaps  \
# basin_id
# AT00001  2019-12-31         24        288     8766            0.0
# AT00002  2019-12-31         62        735    22372            0.0
# AT00003  2019-12-31         35        420    12782            0.0
# AT00004  2019-12-31         22        264     8034            0.0
# AT00005  2019-12-31         30        360    10957            0.0
# ...             ...        ...        ...      ...            ...
# UAGR017  1987-12-31         10        120     3652            0.0
# UAGR018  1987-12-31         10        120     3652            0.0
# UAGR019  1987-12-31         10        120     3652            0.0
# UAGR020  1987-12-31         10        120     3652            0.0
# UAGR021  1987-12-31         10        120     3652            0.0
#
#           num_continuous_days  old_code  new_code gauge_provider
# basin_id
# AT00001                  8766   AT00001  AT000001        AT_EHYD
# AT00002                 22372   AT00002  AT000002        AT_EHYD
# AT00003                 12782   AT00003  AT000003        AT_EHYD
# AT00004                  8034   AT00004  AT000004        AT_EHYD
# AT00005                 10957   AT00005  AT000005        AT_EHYD
# ...                       ...       ...       ...            ...
# UAGR017                  3652   UAGR017  UAGR0017        UA_GRDC
# UAGR018                  3652   UAGR018  UAGR0018        UA_GRDC
# UAGR019                  3652   UAGR019  UAGR0019        UA_GRDC
# UAGR020                  3652   UAGR020  UAGR0020        UA_GRDC
# UAGR021                  3652   UAGR021  UAGR0021        UA_GRDC
#
# [15046 rows x 23 columns]

# %%
# Check the data
network_EU_net[network_EU_net.gauge_provider.isna()]
# Out:
# Empty DataFrame
# Columns: [gauge_id, gauge_name , gauge_country, river, lon, lat, lon_r, lat_r, area_r, elevation, area_c, area_flag, area_perc, start_date, end_date, num_years, num_months, num_days, num_days_gaps, num_continuous_days, old_code, new_code, gauge_provider]
# Index: []
#
# [0 rows x 23 columns]

# %%
network_EU_net.columns
# Out:
# Index(['gauge_id', 'gauge_name ', 'gauge_country', 'river', 'lon', 'lat',
#        'lon_r', 'lat_r', 'area_r', 'elevation', 'area_c', 'area_flag',
#        'area_perc', 'start_date', 'end_date', 'num_years', 'num_months',
#        'num_days', 'num_days_gaps', 'num_continuous_days', 'old_code',
#        'new_code', 'gauge_provider'],
#       dtype='object')

# %% [markdown]
# ## Organize the columns

# %%
network_EU_net.columns = ['gauge_id', 'gauge_name ', 'gauge_country', 'river', 'lon_snap', 'lat_snap',
                          'lon', 'lat', 'area', 'elevation', 'area_calc', 'area_flag',
                          'area_perc', 'start_date', 'end_date', 'num_years', 'num_months',
                          'num_days', 'num_days_gaps', 'num_continuous_days', 'old_code', 'new_code', 'gauge_provider']

network_EU_net = network_EU_net[['gauge_id', 'gauge_name ', 'gauge_country', 'gauge_provider', 'river', 'lon_snap',
                                 'lat_snap', 'lon', 'lat', 'area', 'elevation', 
                                 'area_calc', 'area_flag', 'area_perc',
                                 'start_date', 'end_date', 'num_years', 'num_months', 'num_days',
                                 'num_days_gaps', 'num_continuous_days', 'new_code']]

network_EU_net
# Out:
#          gauge_id          gauge_name  gauge_country gauge_provider  \
# basin_id
# AT00001    200014                Bangs            AT        AT_EHYD
# AT00002    200048  Schruns (Vonbunweg)            AT        AT_EHYD
# AT00003    231662        Loruens-Aeule            AT        AT_EHYD
# AT00004    200592    Kloesterle (OEBB)            AT        AT_EHYD
# AT00005    200097  Buers (Bruecke L82)            AT        AT_EHYD
# ...           ...                  ...           ...            ...
# UAGR017   6682300          BASHTANOVKA            UA        UA_GRDC
# UAGR018   6682500                YALTA            UA        UA_GRDC
# UAGR019   6683010           PIONERSKOE            UA        UA_GRDC
# UAGR020   6683200               TOKMAK            UA        UA_GRDC
# UAGR021   6683300          NOVOSELOVKA            UA        UA_GRDC
#
#               river   lon_snap   lat_snap        lon        lat    area  ...  \
# basin_id                                                                 ...
# AT00001       Rhein   9.534835  47.273748   9.534835  47.273748  4647.9  ...
# AT00002        Litz   9.913677  47.080301   9.913677  47.080301   102.0  ...
# AT00003         Ill   9.847765  47.132821   9.847765  47.132821   535.2  ...
# AT00004      Alfenz  10.061843  47.128994  10.061843  47.128994    66.6  ...
# AT00005      Alvier   9.802668  47.150770   9.802668  47.150770    72.2  ...
# ...             ...        ...        ...        ...        ...     ...  ...
# UAGR017       KACHA  33.894739  44.691884  33.900000  44.683333   321.0  ...
# UAGR018   DERE-KIOY  34.166667  44.500000  34.166667  44.500000    49.7  ...
# UAGR019      SALHYR  34.199841  44.887685  34.200000  44.883333   261.0  ...
# UAGR020      TOKMAK  35.705833  47.251389  35.705833  47.251389   760.0  ...
# UAGR021      KRYNKA  38.144722  48.153333  38.144722  48.153333   582.0  ...
#
#          area_flag  area_perc  start_date   end_date num_years num_months  \
# basin_id
# AT00001          0  -0.440608  1996-01-01 2019-12-31        24        288
# AT00002          0  -0.281373  1958-10-01 2019-12-31        62        735
# AT00003          0  -0.205344  1985-01-02 2019-12-31        35        420
# AT00004          0   0.471471  1998-01-02 2019-12-31        22        264
# AT00005          0  -0.343490  1990-01-01 2019-12-31        30        360
# ...            ...        ...         ...        ...       ...        ...
# UAGR017          0  -1.361371  1978-01-01 1987-12-31        10        120
# UAGR018          0   4.237425  1978-01-01 1987-12-31        10        120
# UAGR019          1   6.233333  1978-01-01 1987-12-31        10        120
# UAGR020          0   3.806184  1978-01-01 1987-12-31        10        120
# UAGR021          0  -3.024055  1978-01-01 1987-12-31        10        120
#
#           num_days  num_days_gaps  num_continuous_days  new_code
# basin_id
# AT00001       8766            0.0                 8766  AT000001
# AT00002      22372            0.0                22372  AT000002
# AT00003      12782            0.0                12782  AT000003
# AT00004       8034            0.0                 8034  AT000004
# AT00005      10957            0.0                10957  AT000005
# ...            ...            ...                  ...       ...
# UAGR017       3652            0.0                 3652  UAGR0017
# UAGR018       3652            0.0                 3652  UAGR0018
# UAGR019       3652            0.0                 3652  UAGR0019
# UAGR020       3652            0.0                 3652  UAGR0020
# UAGR021       3652            0.0                 3652  UAGR0021
#
# [15046 rows x 22 columns]

# %%
# Subset the data for only catchments with valid areas:
timeseries_EU = timeseries_EU.loc[:, catchment_boundaries.index]
network_EU_net = network_EU_net.loc[catchment_boundaries.index, :]
network_EU_net
# Out:
#         gauge_id          gauge_name  gauge_country gauge_provider      river  \
# id
# AT00001   200014                Bangs            AT        AT_EHYD      Rhein
# AT00002   200048  Schruns (Vonbunweg)            AT        AT_EHYD       Litz
# AT00003   231662        Loruens-Aeule            AT        AT_EHYD        Ill
# AT00004   200592    Kloesterle (OEBB)            AT        AT_EHYD     Alfenz
# AT00005   200097  Buers (Bruecke L82)            AT        AT_EHYD     Alvier
# ...          ...                  ...           ...            ...        ...
# UAGR017  6682300          BASHTANOVKA            UA        UA_GRDC      KACHA
# UAGR018  6682500                YALTA            UA        UA_GRDC  DERE-KIOY
# UAGR019  6683010           PIONERSKOE            UA        UA_GRDC     SALHYR
# UAGR020  6683200               TOKMAK            UA        UA_GRDC     TOKMAK
# UAGR021  6683300          NOVOSELOVKA            UA        UA_GRDC     KRYNKA
#
#           lon_snap   lat_snap        lon        lat    area  ... area_flag  \
# id                                                           ...
# AT00001   9.534835  47.273748   9.534835  47.273748  4647.9  ...         0
# AT00002   9.913677  47.080301   9.913677  47.080301   102.0  ...         0
# AT00003   9.847765  47.132821   9.847765  47.132821   535.2  ...         0
# AT00004  10.061843  47.128994  10.061843  47.128994    66.6  ...         0
# AT00005   9.802668  47.150770   9.802668  47.150770    72.2  ...         0
# ...            ...        ...        ...        ...     ...  ...       ...
# UAGR017  33.894739  44.691884  33.900000  44.683333   321.0  ...         0
# UAGR018  34.166667  44.500000  34.166667  44.500000    49.7  ...         0
# UAGR019  34.199841  44.887685  34.200000  44.883333   261.0  ...         1
# UAGR020  35.705833  47.251389  35.705833  47.251389   760.0  ...         0
# UAGR021  38.144722  48.153333  38.144722  48.153333   582.0  ...         0
#
#          area_perc  start_date   end_date num_years num_months  num_days  \
# id
# AT00001  -0.440608  1996-01-01 2019-12-31        24        288      8766
# AT00002  -0.281373  1958-10-01 2019-12-31        62        735     22372
# AT00003  -0.205344  1985-01-02 2019-12-31        35        420     12782
# AT00004   0.471471  1998-01-02 2019-12-31        22        264      8034
# AT00005  -0.343490  1990-01-01 2019-12-31        30        360     10957
# ...            ...         ...        ...       ...        ...       ...
# UAGR017  -1.361371  1978-01-01 1987-12-31        10        120      3652
# UAGR018   4.237425  1978-01-01 1987-12-31        10        120      3652
# UAGR019   6.233333  1978-01-01 1987-12-31        10        120      3652
# UAGR020   3.806184  1978-01-01 1987-12-31        10        120      3652
# UAGR021  -3.024055  1978-01-01 1987-12-31        10        120      3652
#
#          num_days_gaps  num_continuous_days  new_code
# id
# AT00001            0.0                 8766  AT000001
# AT00002            0.0                22372  AT000002
# AT00003            0.0                12782  AT000003
# AT00004            0.0                 8034  AT000004
# AT00005            0.0                10957  AT000005
# ...                ...                  ...       ...
# UAGR017            0.0                 3652  UAGR0017
# UAGR018            0.0                 3652  UAGR0018
# UAGR019            0.0                 3652  UAGR0019
# UAGR020            0.0                 3652  UAGR0020
# UAGR021            0.0                 3652  UAGR0021
#
# [15014 rows x 22 columns]

# %%
# Save the new data:
network_EU_net.to_excel('results/estreams_gauging_stations.xlsx')
#timeseries_EU.to_csv('results/estreams_timeseries_streamflow.csv')

# %% [markdown]
# ### Table with country's summary in the manuscript
# * This code generates Table 1 from the manuscript

# %%
network_EU = pd.read_excel("results/estreams_gauging_stations.xlsx")
network_EU
# Out:
#             id gauge_id          gauge_name  gauge_country gauge_provider  \
# 0      AT00001   200014                Bangs            AT        AT_EHYD
# 1      AT00002   200048  Schruns (Vonbunweg)            AT        AT_EHYD
# 2      AT00003   231662        Loruens-Aeule            AT        AT_EHYD
# 3      AT00004   200592    Kloesterle (OEBB)            AT        AT_EHYD
# 4      AT00005   200097  Buers (Bruecke L82)            AT        AT_EHYD
# ...        ...      ...                  ...           ...            ...
# 15009  UAGR017  6682300          BASHTANOVKA            UA        UA_GRDC
# 15010  UAGR018  6682500                YALTA            UA        UA_GRDC
# 15011  UAGR019  6683010           PIONERSKOE            UA        UA_GRDC
# 15012  UAGR020  6683200               TOKMAK            UA        UA_GRDC
# 15013  UAGR021  6683300          NOVOSELOVKA            UA        UA_GRDC
#
#            river   lon_snap   lat_snap        lon        lat  ...  area_flag  \
# 0          Rhein   9.534835  47.273748   9.534835  47.273748  ...          0
# 1           Litz   9.913677  47.080301   9.913677  47.080301  ...          0
# 2            Ill   9.847765  47.132821   9.847765  47.132821  ...          0
# 3         Alfenz  10.061843  47.128994  10.061843  47.128994  ...          0
# 4         Alvier   9.802668  47.150770   9.802668  47.150770  ...          0
# ...          ...        ...        ...        ...        ...  ...        ...
# 15009      KACHA  33.894739  44.691884  33.900000  44.683333  ...          0
# 15010  DERE-KIOY  34.166667  44.500000  34.166667  44.500000  ...          0
# 15011     SALHYR  34.199841  44.887685  34.200000  44.883333  ...          1
# 15012     TOKMAK  35.705833  47.251389  35.705833  47.251389  ...          0
# 15013     KRYNKA  38.144722  48.153333  38.144722  48.153333  ...          0
#
#       area_perc  start_date   end_date  num_years num_months num_days  \
# 0     -0.440608  1996-01-01 2019-12-31         24        288     8766
# 1     -0.281373  1958-10-01 2019-12-31         62        735    22372
# 2     -0.205344  1985-01-02 2019-12-31         35        420    12782
# 3      0.471471  1998-01-02 2019-12-31         22        264     8034
# 4     -0.343490  1990-01-01 2019-12-31         30        360    10957
# ...         ...         ...        ...        ...        ...      ...
# 15009 -1.361371  1978-01-01 1987-12-31         10        120     3652
# 15010  4.237425  1978-01-01 1987-12-31         10        120     3652
# 15011  6.233333  1978-01-01 1987-12-31         10        120     3652
# 15012  3.806184  1978-01-01 1987-12-31         10        120     3652
# 15013 -3.024055  1978-01-01 1987-12-31         10        120     3652
#
#        num_days_gaps  num_continuous_days  new_code
# 0                0.0                 8766  AT000001
# 1                0.0                22372  AT000002
# 2                0.0                12782  AT000003
# 3                0.0                 8034  AT000004
# 4                0.0                10957  AT000005
# ...              ...                  ...       ...
# 15009            0.0                 3652  UAGR0017
# 15010            0.0                 3652  UAGR0018
# 15011            0.0                 3652  UAGR0019
# 15012            0.0                 3652  UAGR0020
# 15013            0.0                 3652  UAGR0021
#
# [15014 rows x 23 columns]

# %%
network_EU[network_EU.gauge_country == "DE"]
# Out:
#            id    gauge_id                gauge_name  gauge_country  \
# 1840  DE00001     5891200    Alt Ruppin, Schleuse OP            DE
# 1841  DE00002     5871600         Babelsberg-Drewitz            DE
# 1842  DE00003     5530500            Bad Liebenwerda            DE
# 1843  DE00004     5930500               Bad Wilsnack            DE
# 1844  DE00005     5825500  Beeskow, Spreeschleuse UP            DE
# ...       ...         ...                        ...           ...
# 3928  DE02106  5752400000                 Hachelbich            DE
# 3929  DE02107  5752500000                Bleicherode            DE
# 3930  DE02108  5754000000                 Sundhausen            DE
# 3931  DE02109  5755000000                 Nordhausen            DE
# 3932  DE02110  5756600000                     Ilfeld            DE
#
#      gauge_provider            river   lon_snap   lat_snap        lon  \
# 1840          DE_BB             Rhin  12.835157  52.959469  12.835157
# 1841          DE_BB            Nuthe  13.116304  52.362773  13.116304
# 1842          DE_BB  Schwarze Elster  13.394420  51.519043  13.394420
# 1843          DE_BB         Karthane  11.937284  52.956437  11.937284
# 1844          DE_BB            Spree  14.254694  52.171976  14.254694
# ...             ...              ...        ...        ...        ...
# 3928          DE_TH           Wipper  10.973000  51.347000  10.973000
# 3929          DE_TH             Bode  10.593000  51.450000  10.593000
# 3930          DE_TH            Helme  10.810000  51.468000  10.810000
# 3931          DE_TH            Zorge  10.784000  51.507000  10.784000
# 3932          DE_TH             Bere  10.786000  51.598000  10.786000
#
#             lat  ...  area_flag   area_perc  start_date   end_date  num_years  \
# 1840  52.959469  ...          3 -134.602591  1980-11-01 2023-09-25         44
# 1841  52.362773  ...          0   -1.485940  1954-11-01 2023-09-24         70
# 1842  51.519043  ...          3   26.821510  1960-11-01 2023-09-18         64
# 1843  52.956437  ...          0   -1.609808  1975-11-01 2023-09-24         47
# 1844  52.171976  ...          0    3.436989  1950-03-02 2023-09-19         74
# ...         ...  ...        ...         ...         ...        ...        ...
# 3928  51.347000  ...          0    0.000000  1961-11-01 2021-12-31         61
# 3929  51.450000  ...          0    0.000000  1951-11-01 2021-12-31         71
# 3930  51.468000  ...          0    0.299103  1957-11-01 2021-12-31         65
# 3931  51.507000  ...          0    0.527009  1953-11-01 2021-12-31         69
# 3932  51.598000  ...          0   -1.123596  1951-11-01 2021-12-31         71
#
#      num_months num_days  num_days_gaps  num_continuous_days  new_code
# 1840        515    15669            0.0                15669  DEBB0001
# 1841        827    25160            5.0                25124  DEBB0002
# 1842        755    22967            0.0                22967  DEBB0003
# 1843        539    16399         1096.0                14938  DEBB0004
# 1844        883    26865            0.0                26865  DEBB0005
# ...         ...      ...            ...                  ...       ...
# 3928        722    21976            0.0                21976  DETH2106
# 3929        842    25629            0.0                25629  DETH2107
# 3930        770    23437            0.0                23437  DETH2108
# 3931        818    24891            7.0                24650  DETH2109
# 3932        842    25629            0.0                25629  DETH2110
#
# [2093 rows x 23 columns]

# %%
grouped_countries = network_EU.groupby('gauge_provider').count()
network_EU.count()
# Out:
# id                     15014
# gauge_id               15013
# gauge_name             14646
# gauge_country          15014
# gauge_provider         15014
# river                  14599
# lon_snap               15014
# lat_snap               15014
# lon                    15014
# lat                    15014
# area                   13899
# elevation               8795
# area_calc              15014
# area_flag              15014
# area_perc              13898
# start_date             13916
# end_date               13916
# num_years              15014
# num_months             15014
# num_days               15014
# num_days_gaps          13916
# num_continuous_days    15014
# new_code               15014
# dtype: int64

# %%
# Load the world shapefile dataset provided by GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))


# Compute the areas of countries and add them as a new column
world['area_sqkm'] = world['geometry'].to_crs({'proj': 'cea'}).area / 10**6  # Convert to square kilometers


# Display the first few rows of the dataset
europe = world[world.continent == "Europe"]

europe
# Out:
#        pop_est continent              name iso_a3  gdp_md_est  \
# 18   142257519    Europe            Russia    RUS   3745000.0
# 21     5320045    Europe            Norway    -99    364700.0
# 43    67106161    Europe            France    -99   2699000.0
# 110    9960487    Europe            Sweden    SWE    498100.0
# 111    9549747    Europe           Belarus    BLR    165400.0
# 112   44033874    Europe           Ukraine    UKR    352600.0
# 113   38476269    Europe            Poland    POL   1052000.0
# 114    8754413    Europe           Austria    AUT    416600.0
# 115    9850845    Europe           Hungary    HUN    267600.0
# 116    3474121    Europe           Moldova    MDA     18540.0
# 117   21529967    Europe           Romania    ROU    441000.0
# 118    2823859    Europe         Lithuania    LTU     85620.0
# 119    1944643    Europe            Latvia    LVA     50650.0
# 120    1251581    Europe           Estonia    EST     38700.0
# 121   80594017    Europe           Germany    DEU   3979000.0
# 122    7101510    Europe          Bulgaria    BGR    143100.0
# 123   10768477    Europe            Greece    GRC    290500.0
# 125    3047987    Europe           Albania    ALB     33900.0
# 126    4292095    Europe           Croatia    HRV     94240.0
# 127    8236303    Europe       Switzerland    CHE    496300.0
# 128     594130    Europe        Luxembourg    LUX     58740.0
# 129   11491346    Europe           Belgium    BEL    508600.0
# 130   17084719    Europe       Netherlands    NLD    870800.0
# 131   10839514    Europe          Portugal    PRT    297100.0
# 132   48958159    Europe             Spain    ESP   1690000.0
# 133    5011102    Europe           Ireland    IRL    322000.0
# 141   62137802    Europe             Italy    ITA   2221000.0
# 142    5605948    Europe           Denmark    DNK    264800.0
# 143   64769452    Europe    United Kingdom    GBR   2788000.0
# 144     339747    Europe           Iceland    ISL     16150.0
# 150    1972126    Europe          Slovenia    SVN     68350.0
# 151    5491218    Europe           Finland    FIN    224137.0
# 152    5445829    Europe          Slovakia    SVK    168800.0
# 153   10674723    Europe           Czechia    CZE    350900.0
# 170    3856181    Europe  Bosnia and Herz.    BIH     42530.0
# 171    2103721    Europe         Macedonia    MKD     29520.0
# 172    7111024    Europe            Serbia    SRB    101800.0
# 173     642550    Europe        Montenegro    MNE     10610.0
# 174    1895250    Europe            Kosovo    -99     18490.0
#
#                                               geometry     area_sqkm
# 18   MULTIPOLYGON (((178.72530 71.09880, 180.00000 ...  1.702059e+07
# 21   MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...  3.972363e+05
# 43   MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...  6.448677e+05
# 110  POLYGON ((11.02737 58.85615, 11.46827 59.43239...  4.507119e+05
# 111  POLYGON ((28.17671 56.16913, 29.22951 55.91834...  2.089318e+05
# 112  POLYGON ((31.78599 52.10168, 32.15944 52.06125...  5.725398e+05
# 113  POLYGON ((23.48413 53.91250, 23.52754 53.47012...  3.103561e+05
# 114  POLYGON ((16.97967 48.12350, 16.90375 47.71487...  8.508349e+04
# 115  POLYGON ((22.08561 48.42226, 22.64082 48.15024...  9.249455e+04
# 116  POLYGON ((26.61934 48.22073, 26.85782 48.36821...  3.232595e+04
# 117  POLYGON ((28.23355 45.48828, 28.67978 45.30403...  2.383786e+05
# 118  POLYGON ((26.49433 55.61511, 26.58828 55.16718...  6.382005e+04
# 119  POLYGON ((27.28818 57.47453, 27.77002 57.24426...  6.392072e+04
# 120  POLYGON ((27.98113 59.47537, 27.98112 59.47537...  4.466772e+04
# 121  POLYGON ((14.11969 53.75703, 14.35332 53.24817...  3.573990e+05
# 122  POLYGON ((22.65715 44.23492, 22.94483 43.82379...  1.102147e+05
# 123  MULTIPOLYGON (((26.29000 35.29999, 26.16500 35...  1.319931e+05
# 125  POLYGON ((21.02004 40.84273, 20.99999 40.58000...  2.969513e+04
# 126  POLYGON ((16.56481 46.50375, 16.88252 46.38063...  5.755030e+04
# 127  POLYGON ((9.59423 47.52506, 9.63293 47.34760, ...  4.617167e+04
# 128  POLYGON ((6.04307 50.12805, 6.24275 49.90223, ...  2.415601e+03
# 129  POLYGON ((6.15666 50.80372, 6.04307 50.12805, ...  3.013410e+04
# 130  POLYGON ((6.90514 53.48216, 7.09205 53.14404, ...  3.993060e+04
# 131  POLYGON ((-9.03482 41.88057, -8.67195 42.13469...  9.340048e+04
# 132  POLYGON ((-7.45373 37.09779, -7.53711 37.42890...  5.022285e+05
# 133  POLYGON ((-6.19788 53.86757, -6.03299 53.15316...  5.847536e+04
# 141  MULTIPOLYGON (((10.44270 46.89355, 11.04856 46...  3.151160e+05
# 142  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  4.279200e+04
# 143  MULTIPOLYGON (((-6.19788 53.86757, -6.95373 54...  2.499296e+05
# 144  POLYGON ((-14.50870 66.45589, -14.73964 65.808...  1.078850e+05
# 150  POLYGON ((13.80648 46.50931, 14.63247 46.43182...  1.911759e+04
# 151  POLYGON ((28.59193 69.06478, 28.44594 68.36461...  3.412621e+05
# 152  POLYGON ((22.55814 49.08574, 22.28084 48.82539...  4.706978e+04
# 153  POLYGON ((15.01700 51.10667, 15.49097 50.78473...  8.120957e+04
# 170  POLYGON ((18.56000 42.65000, 17.67492 43.02856...  5.061695e+04
# 171  POLYGON ((22.38053 42.32026, 22.88137 41.99930...  2.506160e+04
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...  7.637329e+04
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...  1.344636e+04
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...  1.123192e+04

# %%
# Create a dictionary manually mapping country codes to country names
country_dict = {
    'AT': 'Austria',
    'BA': 'Bosnia and Herz.',
    'BE': 'Belgium',
    'BG': 'Bulgaria',
    'BY': 'Belarus',
    'CH': 'Switzerland',
    'CY': 'Cyprus',
    'CZ': 'Czechia',
    'DE': 'Germany',
    'DK': 'Denmark',
    'EE': 'Estonia',
    'ES': 'Spain',
    'FI': 'Finland',
    'FR': 'France',
    'GB': 'Great Britain',
    'GR': 'Greece',
    'HR': 'Croatia',
    'HU': 'Hungary',
    'IE': 'Ireland',
    'IS': 'Iceland',
    'IT': 'Italy',
    'LT': 'Lithuania',
    'LU': 'Luxembourg',
    'LV': 'Latvia',
    'MD': 'Moldova',
    'MK': 'Macedonia',
    'NI': 'Northern Ireland',
    'NL': 'Netherlands',
    'NO': 'Norway',
    'PL': 'Poland',
    'PT': 'Portugal',
    'RO': 'Romania',
    'RS': 'Serbia',
    'RU': 'Russia',
    'SE': 'Sweden',
    'SI': 'Slovenia',
    'SK': 'Slovakia',
    'TR': 'Turkey',
    'UA': 'Ukraine'    
}

# %%
grouped_countries = network_EU.groupby('gauge_country').count()
grouped_countries = pd.DataFrame(grouped_countries.iloc[:,0])

grouped_countries.columns = ["Number of stations"]
grouped_countries["Code"] = grouped_countries.index

# Assign country names based on country codes
grouped_countries['Country'] = grouped_countries['Code'].map(country_dict)
grouped_countries.reset_index(inplace = True, drop = True)
grouped_countries.set_index("Country", inplace = True)
grouped_countries["Area km2"] = world.set_index("name", inplace = False).area_sqkm

grouped_countries.loc["Great Britain", "Area km2"] = 209331
grouped_countries.loc["Northern Ireland", "Area km2"] = 14130

grouped_countries = grouped_countries[["Code", "Number of stations", "Area km2"]]

grouped_countries.reset_index(inplace = True, drop = False)

grouped_countries.set_index("Code", inplace = True)

# Group by 'gauge_country' and count the number of unique 'gauge_provider' values in each group
grouped_countries["Number of providers"] = network_EU.groupby('gauge_country')['gauge_provider'].nunique()

grouped_countries.reset_index(inplace = True, drop = False)

grouped_countries = grouped_countries[["Country", "Code", "Number of stations", "Number of providers", "Area km2"]]

grouped_countries["Density (stations/100km2)"] = (grouped_countries["Number of stations"] / grouped_countries["Area km2"]) * 100

grouped_countries["Density (stations/100km2)"] = grouped_countries["Density (stations/100km2)"].round(3)
grouped_countries.set_index("Country", inplace = True)

grouped_countries
# Out:
#                  Code  Number of stations  Number of providers      Area km2  \
# Country
# Austria            AT                 582                    1  8.508349e+04
# Bosnia and Herz.   BA                  91                    1  5.061695e+04
# Belgium            BE                 230                    2  3.013410e+04
# Bulgaria           BG                   8                    1  1.102147e+05
# Belarus            BY                  51                    1  2.089318e+05
# Switzerland        CH                 298                    1  4.617167e+04
# Cyprus             CY                  14                    1  6.220762e+03
# Czechia            CZ                 566                    2  8.120957e+04
# Germany            DE                2093                   11  3.573990e+05
# Denmark            DK                1000                    1  4.279200e+04
# Estonia            EE                  54                    1  4.466772e+04
# Spain              ES                1440                    1  5.022285e+05
# Finland            FI                 669                    1  3.412621e+05
# France             FR                3155                    1  6.448677e+05
# Great Britain      GB                 671                    1  2.093310e+05
# Greece             GR                  31                    3  1.319931e+05
# Croatia            HR                 158                    1  5.755030e+04
# Hungary            HU                  65                    2  9.249455e+04
# Ireland            IE                 464                    2  5.847536e+04
# Iceland            IS                  25                    1  1.078850e+05
# Italy              IT                 767                   13  3.151160e+05
# Lithuania          LT                  76                    1  6.382005e+04
# Luxembourg         LU                  19                    1  2.415601e+03
# Latvia             LV                  61                    1  6.392072e+04
# Moldova            MD                   2                    1  3.232595e+04
# Macedonia          MK                   1                    1  2.506160e+04
# Northern Ireland   NI                  51                    1  1.413000e+04
# Netherlands        NL                  17                    1  3.993060e+04
# Norway             NO                 189                    1  3.972363e+05
# Poland             PL                1287                    1  3.103561e+05
# Portugal           PT                 280                    1  9.340048e+04
# Romania            RO                  18                    1  2.383786e+05
# Serbia             RS                   6                    1  7.637329e+04
# Russia             RU                  98                    1  1.702059e+07
# Sweden             SE                 290                    1  4.507119e+05
# Slovenia           SI                 117                    1  1.911759e+04
# Slovakia           SK                  21                    1  4.706978e+04
# Turkey             TR                  28                    1  7.986473e+05
# Ukraine            UA                  21                    1  5.725398e+05
#
#                   Density (stations/100km2)
# Country
# Austria                               0.684
# Bosnia and Herz.                      0.180
# Belgium                               0.763
# Bulgaria                              0.007
# Belarus                               0.024
# Switzerland                           0.645
# Cyprus                                0.225
# Czechia                               0.697
# Germany                               0.586
# Denmark                               2.337
# Estonia                               0.121
# Spain                                 0.287
# Finland                               0.196
# France                                0.489
# Great Britain                         0.321
# Greece                                0.023
# Croatia                               0.275
# Hungary                               0.070
# Ireland                               0.793
# Iceland                               0.023
# Italy                                 0.243
# Lithuania                             0.119
# Luxembourg                            0.787
# Latvia                                0.095
# Moldova                               0.006
# Macedonia                             0.004
# Northern Ireland                      0.361
# Netherlands                           0.043
# Norway                                0.048
# Poland                                0.415
# Portugal                              0.300
# Romania                               0.008
# Serbia                                0.008
# Russia                                0.001
# Sweden                                0.064
# Slovenia                              0.612
# Slovakia                              0.045
# Turkey                                0.004
# Ukraine                               0.004

# %%
# Save the new data:
grouped_countries.to_excel('results/estreams_table_countries_summary.xlsx')

# %% [markdown]
# ## End
